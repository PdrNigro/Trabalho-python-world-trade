# %%
import os
import pandas as pd

# %%
print('Diretório inicial: {}'.format(os.getcwd()))
os.chdir('C:/Users/ppomp/Documents/Python')
# Out:
# Diretório inicial: C:\Users\ppomp

# %%
print('novo diretório: {}'.format(os.getcwd()))
# Out:
# novo diretório: C:\Users\ppomp\Documents\Python

# %%
tabela_bruta_comercio_internacional = pd.read_csv('WTD_trabalho.py.csv', sep = ',',  encoding = 'ISO-8859-1')
# Out:
# C:\Users\ppomp\AppData\Local\Temp\ipykernel_9440\2120908095.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_bruta_comercio_internacional = pd.read_csv('WTD_trabalho.py.csv', sep = ',',  encoding = 'ISO-8859-1')

# %%
#aumentar número de linhas e colunas visualizáveis para ter um entendimento melhor da base d 
pd.options.display.max_rows = 30
pd.options.display.max_columns = 24
pd.options.display.max_colwidth = 100

tabela_bruta_comercio_internacional
# Out:
#                            Indicator Category Indicator Code  \
# 0      Merchandise trade - indices and prices     ITS_MTP_AM
# 1      Merchandise trade - indices and prices     ITS_MTP_AM
# 2      Merchandise trade - indices and prices     ITS_MTP_AM
# 3      Merchandise trade - indices and prices     ITS_MTP_AM
# 4      Merchandise trade - indices and prices     ITS_MTP_AM
# 5      Merchandise trade - indices and prices     ITS_MTP_AM
# 6      Merchandise trade - indices and prices     ITS_MTP_AM
# 7      Merchandise trade - indices and prices     ITS_MTP_AM
# 8      Merchandise trade - indices and prices     ITS_MTP_AM
# 9      Merchandise trade - indices and prices     ITS_MTP_AM
# 10     Merchandise trade - indices and prices     ITS_MTP_AM
# 11     Merchandise trade - indices and prices     ITS_MTP_AM
# 12     Merchandise trade - indices and prices     ITS_MTP_AM
# 13     Merchandise trade - indices and prices     ITS_MTP_AM
# 14     Merchandise trade - indices and prices     ITS_MTP_AM
# ...                                       ...            ...
# 97649            Trade in commercial services      ITS_CS_QX
# 97650            Trade in commercial services      ITS_CS_QX
# 97651            Trade in commercial services      ITS_CS_QX
# 97652            Trade in commercial services      ITS_CS_QX
# 97653            Trade in commercial services      ITS_CS_QX
# 97654            Trade in commercial services      ITS_CS_QX
# 97655            Trade in commercial services      ITS_CS_QX
# 97656            Trade in commercial services      ITS_CS_QX
# 97657            Trade in commercial services      ITS_CS_QX
# 97658            Trade in commercial services      ITS_CS_QX
# 97659            Trade in commercial services      ITS_CS_QX
# 97660            Trade in commercial services      ITS_CS_QX
# 97661            Trade in commercial services      ITS_CS_QX
# 97662            Trade in commercial services      ITS_CS_QX
# 97663            Trade in commercial services      ITS_CS_QX
#
#                                                     Indicator  \
# 0           Merchandise import value chained indices - annual
# 1           Merchandise import value chained indices - annual
# 2           Merchandise import value chained indices - annual
# 3           Merchandise import value chained indices - annual
# 4           Merchandise import value chained indices - annual
# 5           Merchandise import value chained indices - annual
# 6           Merchandise import value chained indices - annual
# 7           Merchandise import value chained indices - annual
# 8           Merchandise import value chained indices - annual
# 9           Merchandise import value chained indices - annual
# 10          Merchandise import value chained indices - annual
# 11          Merchandise import value chained indices - annual
# 12          Merchandise import value chained indices - annual
# 13          Merchandise import value chained indices - annual
# 14          Merchandise import value chained indices - annual
# ...                                                       ...
# 97649  Commercial services exports by main sector  quarterly
# 97650  Commercial services exports by main sector  quarterly
# 97651  Commercial services exports by main sector  quarterly
# 97652  Commercial services exports by main sector  quarterly
# 97653  Commercial services exports by main sector  quarterly
# 97654  Commercial services exports by main sector  quarterly
# 97655  Commercial services exports by main sector  quarterly
# 97656  Commercial services exports by main sector  quarterly
# 97657  Commercial services exports by main sector  quarterly
# 97658  Commercial services exports by main sector  quarterly
# 97659  Commercial services exports by main sector  quarterly
# 97660  Commercial services exports by main sector  quarterly
# 97661  Commercial services exports by main sector  quarterly
# 97662  Commercial services exports by main sector  quarterly
# 97663  Commercial services exports by main sector  quarterly
#
#       Reporting Economy Code Reporting Economy ISO3A Code  \
# 0                        000                          NaN
# 1                        004                          AFG
# 2                        008                          ALB
# 3                        012                          DZA
# 4                        016                          ASM
# 5                        024                          AGO
# 6                        028                          ATG
# 7                        031                          AZE
# 8                        032                          ARG
# 9                        036                          AUS
# 10                       040                          AUT
# 11                       044                          BHS
# 12                       048                          BHR
# 13                       050                          BGD
# 14                       051                          ARM
# ...                      ...                          ...
# 97649                    927                          NaN
# 97650                    927                          NaN
# 97651                    927                          NaN
# 97652                    927                          NaN
# 97653                    927                          NaN
# 97654                    927                          NaN
# 97655                    927                          NaN
# 97656                    927                          NaN
# 97657                    927                          NaN
# 97658                    927                          NaN
# 97659                    927                          NaN
# 97660                    927                          NaN
# 97661                    927                          NaN
# 97662                    927                          NaN
# 97663                    927                          NaN
#
#          Reporting Economy Partner Economy Code Partner Economy ISO3A Code  \
# 0                    World                  000                        NaN
# 1              Afghanistan                  000                        NaN
# 2                  Albania                  000                        NaN
# 3                  Algeria                  000                        NaN
# 4           American Samoa                  000                        NaN
# 5                   Angola                  000                        NaN
# 6      Antigua and Barbuda                  000                        NaN
# 7               Azerbaijan                  000                        NaN
# 8                Argentina                  000                        NaN
# 9                Australia                  000                        NaN
# 10                 Austria                  000                        NaN
# 11                 Bahamas                  000                        NaN
# 12     Bahrain, Kingdom of                  000                        NaN
# 13              Bangladesh                  000                        NaN
# 14                 Armenia                  000                        NaN
# ...                    ...                  ...                        ...
# 97649       Euro Area (19)                  ZX9                        NaN
# 97650       Euro Area (19)                  ZX9                        NaN
# 97651       Euro Area (19)                  ZX9                        NaN
# 97652       Euro Area (19)                  ZX9                        NaN
# 97653       Euro Area (19)                  ZX9                        NaN
# 97654       Euro Area (19)                  ZX9                        NaN
# 97655       Euro Area (19)                  ZX9                        NaN
# 97656       Euro Area (19)                  ZX9                        NaN
# 97657       Euro Area (19)                  ZX9                        NaN
# 97658       Euro Area (19)                  ZX9                        NaN
# 97659       Euro Area (19)                  ZX9                        NaN
# 97660       Euro Area (19)                  ZX9                        NaN
# 97661       Euro Area (19)                  ZX9                        NaN
# 97662       Euro Area (19)                  ZX9                        NaN
# 97663       Euro Area (19)                  ZX9                        NaN
#
#                   Partner Economy Product/Sector Classification Code  \
# 0                           World                              SITC3
# 1                           World                              SITC3
# 2                           World                              SITC3
# 3                           World                              SITC3
# 4                           World                              SITC3
# 5                           World                              SITC3
# 6                           World                              SITC3
# 7                           World                              SITC3
# 8                           World                              SITC3
# 9                           World                              SITC3
# 10                          World                              SITC3
# 11                          World                              SITC3
# 12                          World                              SITC3
# 13                          World                              SITC3
# 14                          World                              SITC3
# ...                           ...                                ...
# 97649  Extra Euro Area (19) Trade                               BOP6
# 97650  Extra Euro Area (19) Trade                               BOP6
# 97651  Extra Euro Area (19) Trade                               BOP6
# 97652  Extra Euro Area (19) Trade                               BOP6
# 97653  Extra Euro Area (19) Trade                               BOP6
# 97654  Extra Euro Area (19) Trade                               BOP6
# 97655  Extra Euro Area (19) Trade                               BOP6
# 97656  Extra Euro Area (19) Trade                               BOP6
# 97657  Extra Euro Area (19) Trade                               BOP6
# 97658  Extra Euro Area (19) Trade                               BOP6
# 97659  Extra Euro Area (19) Trade                               BOP6
# 97660  Extra Euro Area (19) Trade                               BOP6
# 97661  Extra Euro Area (19) Trade                               BOP6
# 97662  Extra Euro Area (19) Trade                               BOP6
# 97663  Extra Euro Area (19) Trade                               BOP6
#
#                                              Product/Sector Classification  \
# 0                               Merchandise - SITC Revision 3 (aggregates)
# 1                               Merchandise - SITC Revision 3 (aggregates)
# 2                               Merchandise - SITC Revision 3 (aggregates)
# 3                               Merchandise - SITC Revision 3 (aggregates)
# 4                               Merchandise - SITC Revision 3 (aggregates)
# 5                               Merchandise - SITC Revision 3 (aggregates)
# 6                               Merchandise - SITC Revision 3 (aggregates)
# 7                               Merchandise - SITC Revision 3 (aggregates)
# 8                               Merchandise - SITC Revision 3 (aggregates)
# 9                               Merchandise - SITC Revision 3 (aggregates)
# 10                              Merchandise - SITC Revision 3 (aggregates)
# 11                              Merchandise - SITC Revision 3 (aggregates)
# 12                              Merchandise - SITC Revision 3 (aggregates)
# 13                              Merchandise - SITC Revision 3 (aggregates)
# 14                              Merchandise - SITC Revision 3 (aggregates)
# ...                                                                    ...
# 97649  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97650  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97651  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97652  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97653  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97654  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97655  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97656  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97657  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97658  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97659  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97660  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97661  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97662  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97663  Services - Extended Balance of Payments Classification (EBOPS 2010)
#
#       Product/Sector Code             Product/Sector Period Code  \
# 0                      TO          Total merchandise           A
# 1                      TO          Total merchandise           A
# 2                      TO          Total merchandise           A
# 3                      TO          Total merchandise           A
# 4                      TO          Total merchandise           A
# 5                      TO          Total merchandise           A
# 6                      TO          Total merchandise           A
# 7                      TO          Total merchandise           A
# 8                      TO          Total merchandise           A
# 9                      TO          Total merchandise           A
# 10                     TO          Total merchandise           A
# 11                     TO          Total merchandise           A
# 12                     TO          Total merchandise           A
# 13                     TO          Total merchandise           A
# 14                     TO          Total merchandise           A
# ...                   ...                        ...         ...
# 97649                SOX1  Other commercial services          Q1
# 97650                SOX1  Other commercial services          Q1
# 97651                SOX1  Other commercial services          Q2
# 97652                SOX1  Other commercial services          Q3
# 97653                SOX1  Other commercial services          Q4
# 97654                SPX1  Memo item: Other services          Q1
# 97655                SPX1  Memo item: Other services          Q1
# 97656                SPX1  Memo item: Other services          Q2
# 97657                SPX1  Memo item: Other services          Q3
# 97658                SPX1  Memo item: Other services          Q4
# 97659                SPX4     Goods-related services          Q1
# 97660                SPX4     Goods-related services          Q1
# 97661                SPX4     Goods-related services          Q2
# 97662                SPX4     Goods-related services          Q3
# 97663                SPX4     Goods-related services          Q4
#
#                Period Frequency Code  Frequency Unit Code               Unit  \
# 0              Annual              A     Annual       IDP  Previous year=100
# 1              Annual              A     Annual       IDP  Previous year=100
# 2              Annual              A     Annual       IDP  Previous year=100
# 3              Annual              A     Annual       IDP  Previous year=100
# 4              Annual              A     Annual       IDP  Previous year=100
# 5              Annual              A     Annual       IDP  Previous year=100
# 6              Annual              A     Annual       IDP  Previous year=100
# 7              Annual              A     Annual       IDP  Previous year=100
# 8              Annual              A     Annual       IDP  Previous year=100
# 9              Annual              A     Annual       IDP  Previous year=100
# 10             Annual              A     Annual       IDP  Previous year=100
# 11             Annual              A     Annual       IDP  Previous year=100
# 12             Annual              A     Annual       IDP  Previous year=100
# 13             Annual              A     Annual       IDP  Previous year=100
# 14             Annual              A     Annual       IDP  Previous year=100
# ...               ...            ...        ...       ...                ...
# 97649   First Quarter              Q  Quarterly       USM  Million US dollar
# 97650   First Quarter              Q  Quarterly       USM  Million US dollar
# 97651  Second Quarter              Q  Quarterly       USM  Million US dollar
# 97652   Third Quarter              Q  Quarterly       USM  Million US dollar
# 97653  Fourth Quarter              Q  Quarterly       USM  Million US dollar
# 97654   First Quarter              Q  Quarterly       USM  Million US dollar
# 97655   First Quarter              Q  Quarterly       USM  Million US dollar
# 97656  Second Quarter              Q  Quarterly       USM  Million US dollar
# 97657   Third Quarter              Q  Quarterly       USM  Million US dollar
# 97658  Fourth Quarter              Q  Quarterly       USM  Million US dollar
# 97659   First Quarter              Q  Quarterly       USM  Million US dollar
# 97660   First Quarter              Q  Quarterly       USM  Million US dollar
# 97661  Second Quarter              Q  Quarterly       USM  Million US dollar
# 97662   Third Quarter              Q  Quarterly       USM  Million US dollar
# 97663  Fourth Quarter              Q  Quarterly       USM  Million US dollar
#
#        Year Value Flag Code Value Flag  Text Value          Value
# 0      2021             NaN        NaN         NaN     126.432000
# 1      2021               E   Estimate         NaN      85.260000
# 2      2021             NaN        NaN         NaN     138.571000
# 3      2021               E   Estimate         NaN     104.676000
# 4      2021               E   Estimate         NaN     101.862000
# 5      2021             NaN        NaN         NaN     123.595000
# 6      2021             NaN        NaN         NaN     119.555000
# 7      2021             NaN        NaN         NaN     109.074000
# 8      2021             NaN        NaN         NaN     149.183000
# 9      2021             NaN        NaN         NaN     123.293000
# 10     2021             NaN        NaN         NaN     127.295000
# 11     2021             NaN        NaN         NaN     158.167000
# 12     2021             NaN        NaN         NaN     111.866000
# 13     2021               E   Estimate         NaN     152.352000
# 14     2021             NaN        NaN         NaN     117.492000
# ...     ...             ...        ...         ...            ...
# 97649  2022             NaN        NaN         NaN  203502.709419
# 97650  2021             NaN        NaN         NaN  187885.142562
# 97651  2021             NaN        NaN         NaN  203189.612267
# 97652  2021             NaN        NaN         NaN  205424.496761
# 97653  2021             NaN        NaN         NaN  229442.725629
# 97654  2022             NaN        NaN         NaN  206988.904456
# 97655  2021             NaN        NaN         NaN  191037.023933
# 97656  2021             NaN        NaN         NaN  206643.150756
# 97657  2021             NaN        NaN         NaN  209071.699273
# 97658  2021             NaN        NaN         NaN  233168.332547
# 97659  2022             NaN        NaN         NaN   15312.113403
# 97660  2021             NaN        NaN         NaN   13330.434057
# 97661  2021             NaN        NaN         NaN   13603.131178
# 97662  2021             NaN        NaN         NaN   13175.430665
# 97663  2021             NaN        NaN         NaN   15603.408962
#
# [97664 rows x 24 columns]

# %%
##### criar uma lista com os nomes do todas as colunas para ter um acesso rápido a tais informações
cabeçalho = list(tabela_bruta_comercio_internacional.columns.values)
print(cabeçalho)

#analisando a tabela, ficoou claro que ela mistura diferentes tipos de informações, para lidar com isso,
#criar lista de categorias, com o intuito de dividir o data frame em vários outros para cada categoria,
#obtendo, assim, informações mais úteis

#para tanto, transformar a primeira coluna em uma lista
lista_categorias_repetidos = tabela_bruta_comercio_internacional['Indicator Category'].tolist()

#os dados repetidos e o excesso de linhas torna difícil se aproveitar da lista
#eliminar elementos repetidos com list comp.
lista_categorias = []
[lista_categorias.append(categoria) for categoria in lista_categorias_repetidos if categoria not in lista_categorias]
print(lista_categorias)
# Out:
# ['Indicator Category', 'Indicator Code', 'Indicator', 'Reporting Economy Code', 'Reporting Economy ISO3A Code', 'Reporting Economy', 'Partner Economy Code', 'Partner Economy ISO3A Code', 'Partner Economy', 'Product/Sector Classification Code', 'Product/Sector Classification', 'Product/Sector Code', 'Product/Sector', 'Period Code', 'Period', 'Frequency Code', 'Frequency', 'Unit Code', 'Unit', 'Year', 'Value Flag Code', 'Value Flag', 'Text Value', 'Value']
# ['Merchandise trade - indices and prices', 'Merchandise trade values', 'Trade in commercial services']

# %%
#tendo as categorias, usar df.loc para construir tabelas separadas de cada categoria

index_df_ic = tabela_bruta_comercio_internacional.loc[tabela_bruta_comercio_internacional['Indicator Category'] == str(lista_categorias[0])]
index_df_ic
# Out:
#                           Indicator Category Indicator Code  \
# 0     Merchandise trade - indices and prices     ITS_MTP_AM
# 1     Merchandise trade - indices and prices     ITS_MTP_AM
# 2     Merchandise trade - indices and prices     ITS_MTP_AM
# 3     Merchandise trade - indices and prices     ITS_MTP_AM
# 4     Merchandise trade - indices and prices     ITS_MTP_AM
# 5     Merchandise trade - indices and prices     ITS_MTP_AM
# 6     Merchandise trade - indices and prices     ITS_MTP_AM
# 7     Merchandise trade - indices and prices     ITS_MTP_AM
# 8     Merchandise trade - indices and prices     ITS_MTP_AM
# 9     Merchandise trade - indices and prices     ITS_MTP_AM
# 10    Merchandise trade - indices and prices     ITS_MTP_AM
# 11    Merchandise trade - indices and prices     ITS_MTP_AM
# 12    Merchandise trade - indices and prices     ITS_MTP_AM
# 13    Merchandise trade - indices and prices     ITS_MTP_AM
# 14    Merchandise trade - indices and prices     ITS_MTP_AM
# ...                                      ...            ...
# 6289  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6290  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6291  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6292  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6293  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6294  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6295  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6296  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6297  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6298  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6299  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6300  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6301  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6302  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6303  Merchandise trade - indices and prices  ITS_MTP_QXVSA
#
#                                               Indicator  \
# 0     Merchandise import value chained indices - annual
# 1     Merchandise import value chained indices - annual
# 2     Merchandise import value chained indices - annual
# 3     Merchandise import value chained indices - annual
# 4     Merchandise import value chained indices - annual
# 5     Merchandise import value chained indices - annual
# 6     Merchandise import value chained indices - annual
# 7     Merchandise import value chained indices - annual
# 8     Merchandise import value chained indices - annual
# 9     Merchandise import value chained indices - annual
# 10    Merchandise import value chained indices - annual
# 11    Merchandise import value chained indices - annual
# 12    Merchandise import value chained indices - annual
# 13    Merchandise import value chained indices - annual
# 14    Merchandise import value chained indices - annual
# ...                                                 ...
# 6289  Merchandise export volume indices, seasonally ...
# 6290  Merchandise export volume indices, seasonally ...
# 6291  Merchandise export volume indices, seasonally ...
# 6292  Merchandise export volume indices, seasonally ...
# 6293  Merchandise export volume indices, seasonally ...
# 6294  Merchandise export volume indices, seasonally ...
# 6295  Merchandise export volume indices, seasonally ...
# 6296  Merchandise export volume indices, seasonally ...
# 6297  Merchandise export volume indices, seasonally ...
# 6298  Merchandise export volume indices, seasonally ...
# 6299  Merchandise export volume indices, seasonally ...
# 6300  Merchandise export volume indices, seasonally ...
# 6301  Merchandise export volume indices, seasonally ...
# 6302  Merchandise export volume indices, seasonally ...
# 6303  Merchandise export volume indices, seasonally ...
#
#      Reporting Economy Code Reporting Economy ISO3A Code  \
# 0                       000                          NaN
# 1                       004                          AFG
# 2                       008                          ALB
# 3                       012                          DZA
# 4                       016                          ASM
# 5                       024                          AGO
# 6                       028                          ATG
# 7                       031                          AZE
# 8                       032                          ARG
# 9                       036                          AUS
# 10                      040                          AUT
# 11                      044                          BHS
# 12                      048                          BHR
# 13                      050                          BGD
# 14                      051                          ARM
# ...                     ...                          ...
# 6289                    985                          NaN
# 6290                    985                          NaN
# 6291                    985                          NaN
# 6292                    986                          NaN
# 6293                    986                          NaN
# 6294                    986                          NaN
# 6295                    986                          NaN
# 6296                    986                          NaN
# 6297                    986                          NaN
# 6298                    997                          NaN
# 6299                    997                          NaN
# 6300                    997                          NaN
# 6301                    997                          NaN
# 6302                    997                          NaN
# 6303                    997                          NaN
#
#                 Reporting Economy Partner Economy Code  \
# 0                           World                  000
# 1                     Afghanistan                  000
# 2                         Albania                  000
# 3                         Algeria                  000
# 4                  American Samoa                  000
# 5                          Angola                  000
# 6             Antigua and Barbuda                  000
# 7                      Azerbaijan                  000
# 8                       Argentina                  000
# 9                       Australia                  000
# 10                        Austria                  000
# 11                        Bahamas                  000
# 12            Bahrain, Kingdom of                  000
# 13                     Bangladesh                  000
# 14                        Armenia                  000
# ...                           ...                  ...
# 6289                         G-20                  000
# 6290                         G-20                  000
# 6291                         G-20                  000
# 6292  Africa, CIS and Middle East                  000
# 6293  Africa, CIS and Middle East                  000
# 6294  Africa, CIS and Middle East                  000
# 6295  Africa, CIS and Middle East                  000
# 6296  Africa, CIS and Middle East                  000
# 6297  Africa, CIS and Middle East                  000
# 6298    Least-developed countries                  000
# 6299    Least-developed countries                  000
# 6300    Least-developed countries                  000
# 6301    Least-developed countries                  000
# 6302    Least-developed countries                  000
# 6303    Least-developed countries                  000
#
#      Partner Economy ISO3A Code Partner Economy  \
# 0                           NaN           World
# 1                           NaN           World
# 2                           NaN           World
# 3                           NaN           World
# 4                           NaN           World
# 5                           NaN           World
# 6                           NaN           World
# 7                           NaN           World
# 8                           NaN           World
# 9                           NaN           World
# 10                          NaN           World
# 11                          NaN           World
# 12                          NaN           World
# 13                          NaN           World
# 14                          NaN           World
# ...                         ...             ...
# 6289                        NaN           World
# 6290                        NaN           World
# 6291                        NaN           World
# 6292                        NaN           World
# 6293                        NaN           World
# 6294                        NaN           World
# 6295                        NaN           World
# 6296                        NaN           World
# 6297                        NaN           World
# 6298                        NaN           World
# 6299                        NaN           World
# 6300                        NaN           World
# 6301                        NaN           World
# 6302                        NaN           World
# 6303                        NaN           World
#
#      Product/Sector Classification Code  \
# 0                                 SITC3
# 1                                 SITC3
# 2                                 SITC3
# 3                                 SITC3
# 4                                 SITC3
# 5                                 SITC3
# 6                                 SITC3
# 7                                 SITC3
# 8                                 SITC3
# 9                                 SITC3
# 10                                SITC3
# 11                                SITC3
# 12                                SITC3
# 13                                SITC3
# 14                                SITC3
# ...                                 ...
# 6289                              SITC3
# 6290                              SITC3
# 6291                              SITC3
# 6292                              SITC3
# 6293                              SITC3
# 6294                              SITC3
# 6295                              SITC3
# 6296                              SITC3
# 6297                              SITC3
# 6298                              SITC3
# 6299                              SITC3
# 6300                              SITC3
# 6301                              SITC3
# 6302                              SITC3
# 6303                              SITC3
#
#                    Product/Sector Classification Product/Sector Code  \
# 0     Merchandise - SITC Revision 3 (aggregates)                  TO
# 1     Merchandise - SITC Revision 3 (aggregates)                  TO
# 2     Merchandise - SITC Revision 3 (aggregates)                  TO
# 3     Merchandise - SITC Revision 3 (aggregates)                  TO
# 4     Merchandise - SITC Revision 3 (aggregates)                  TO
# 5     Merchandise - SITC Revision 3 (aggregates)                  TO
# 6     Merchandise - SITC Revision 3 (aggregates)                  TO
# 7     Merchandise - SITC Revision 3 (aggregates)                  TO
# 8     Merchandise - SITC Revision 3 (aggregates)                  TO
# 9     Merchandise - SITC Revision 3 (aggregates)                  TO
# 10    Merchandise - SITC Revision 3 (aggregates)                  TO
# 11    Merchandise - SITC Revision 3 (aggregates)                  TO
# 12    Merchandise - SITC Revision 3 (aggregates)                  TO
# 13    Merchandise - SITC Revision 3 (aggregates)                  TO
# 14    Merchandise - SITC Revision 3 (aggregates)                  TO
# ...                                          ...                 ...
# 6289  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6290  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6291  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6292  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6293  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6294  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6295  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6296  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6297  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6298  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6299  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6300  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6301  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6302  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6303  Merchandise - SITC Revision 3 (aggregates)                  TO
#
#          Product/Sector Period Code          Period Frequency Code  Frequency  \
# 0     Total merchandise           A          Annual              A     Annual
# 1     Total merchandise           A          Annual              A     Annual
# 2     Total merchandise           A          Annual              A     Annual
# 3     Total merchandise           A          Annual              A     Annual
# 4     Total merchandise           A          Annual              A     Annual
# 5     Total merchandise           A          Annual              A     Annual
# 6     Total merchandise           A          Annual              A     Annual
# 7     Total merchandise           A          Annual              A     Annual
# 8     Total merchandise           A          Annual              A     Annual
# 9     Total merchandise           A          Annual              A     Annual
# 10    Total merchandise           A          Annual              A     Annual
# 11    Total merchandise           A          Annual              A     Annual
# 12    Total merchandise           A          Annual              A     Annual
# 13    Total merchandise           A          Annual              A     Annual
# 14    Total merchandise           A          Annual              A     Annual
# ...                 ...         ...             ...            ...        ...
# 6289  Total merchandise          Q2  Second Quarter              Q  Quarterly
# 6290  Total merchandise          Q3   Third Quarter              Q  Quarterly
# 6291  Total merchandise          Q4  Fourth Quarter              Q  Quarterly
# 6292  Total merchandise          Q1   First Quarter              Q  Quarterly
# 6293  Total merchandise          Q1   First Quarter              Q  Quarterly
# 6294  Total merchandise          Q2  Second Quarter              Q  Quarterly
# 6295  Total merchandise          Q2  Second Quarter              Q  Quarterly
# 6296  Total merchandise          Q3   Third Quarter              Q  Quarterly
# 6297  Total merchandise          Q4  Fourth Quarter              Q  Quarterly
# 6298  Total merchandise          Q1   First Quarter              Q  Quarterly
# 6299  Total merchandise          Q1   First Quarter              Q  Quarterly
# 6300  Total merchandise          Q2  Second Quarter              Q  Quarterly
# 6301  Total merchandise          Q2  Second Quarter              Q  Quarterly
# 6302  Total merchandise          Q3   Third Quarter              Q  Quarterly
# 6303  Total merchandise          Q4  Fourth Quarter              Q  Quarterly
#
#      Unit Code               Unit  Year Value Flag Code Value Flag  \
# 0          IDP  Previous year=100  2021             NaN        NaN
# 1          IDP  Previous year=100  2021               E   Estimate
# 2          IDP  Previous year=100  2021             NaN        NaN
# 3          IDP  Previous year=100  2021               E   Estimate
# 4          IDP  Previous year=100  2021               E   Estimate
# 5          IDP  Previous year=100  2021             NaN        NaN
# 6          IDP  Previous year=100  2021             NaN        NaN
# 7          IDP  Previous year=100  2021             NaN        NaN
# 8          IDP  Previous year=100  2021             NaN        NaN
# 9          IDP  Previous year=100  2021             NaN        NaN
# 10         IDP  Previous year=100  2021             NaN        NaN
# 11         IDP  Previous year=100  2021             NaN        NaN
# 12         IDP  Previous year=100  2021             NaN        NaN
# 13         IDP  Previous year=100  2021               E   Estimate
# 14         IDP  Previous year=100  2021             NaN        NaN
# ...        ...                ...   ...             ...        ...
# 6289    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6290    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6291    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6292    ID05Q1         2005Q1=100  2022             NaN        NaN
# 6293    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6294    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6295    ID05Q1         2005Q1=100  2022             NaN        NaN
# 6296    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6297    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6298    ID05Q1         2005Q1=100  2022             NaN        NaN
# 6299    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6300    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6301    ID05Q1         2005Q1=100  2022             NaN        NaN
# 6302    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6303    ID05Q1         2005Q1=100  2021             NaN        NaN
#
#       Text Value    Value
# 0            NaN  126.432
# 1            NaN   85.260
# 2            NaN  138.571
# 3            NaN  104.676
# 4            NaN  101.862
# 5            NaN  123.595
# 6            NaN  119.555
# 7            NaN  109.074
# 8            NaN  149.183
# 9            NaN  123.293
# 10           NaN  127.295
# 11           NaN  158.167
# 12           NaN  111.866
# 13           NaN  152.352
# 14           NaN  117.492
# ...          ...      ...
# 6289         NaN  163.821
# 6290         NaN  162.621
# 6291         NaN  167.475
# 6292         NaN  131.840
# 6293         NaN  114.546
# 6294         NaN  120.640
# 6295         NaN  125.806
# 6296         NaN  121.085
# 6297         NaN  124.486
# 6298         NaN  231.797
# 6299         NaN  195.518
# 6300         NaN  198.815
# 6301         NaN  241.494
# 6302         NaN  196.402
# 6303         NaN  213.508
#
# [6304 rows x 24 columns]

# %%
values_df_ic = tabela_bruta_comercio_internacional.loc[tabela_bruta_comercio_internacional['Indicator Category'] == str(lista_categorias[1])]
values_df_ic
# Out:
#              Indicator Category Indicator Code  \
# 6304   Merchandise trade values     ITS_MTV_AM
# 6305   Merchandise trade values     ITS_MTV_AM
# 6306   Merchandise trade values     ITS_MTV_AM
# 6307   Merchandise trade values     ITS_MTV_AM
# 6308   Merchandise trade values     ITS_MTV_AM
# 6309   Merchandise trade values     ITS_MTV_AM
# 6310   Merchandise trade values     ITS_MTV_AM
# 6311   Merchandise trade values     ITS_MTV_AM
# 6312   Merchandise trade values     ITS_MTV_AM
# 6313   Merchandise trade values     ITS_MTV_AM
# 6314   Merchandise trade values     ITS_MTV_AM
# 6315   Merchandise trade values     ITS_MTV_AM
# 6316   Merchandise trade values     ITS_MTV_AM
# 6317   Merchandise trade values     ITS_MTV_AM
# 6318   Merchandise trade values     ITS_MTV_AM
# ...                         ...            ...
# 10991  Merchandise trade values     ITS_MTV_QX
# 10992  Merchandise trade values     ITS_MTV_QX
# 10993  Merchandise trade values     ITS_MTV_QX
# 10994  Merchandise trade values     ITS_MTV_QX
# 10995  Merchandise trade values     ITS_MTV_QX
# 10996  Merchandise trade values     ITS_MTV_QX
# 10997  Merchandise trade values     ITS_MTV_QX
# 10998  Merchandise trade values     ITS_MTV_QX
# 10999  Merchandise trade values     ITS_MTV_QX
# 11000  Merchandise trade values     ITS_MTV_QX
# 11001  Merchandise trade values     ITS_MTV_QX
# 11002  Merchandise trade values     ITS_MTV_QX
# 11003  Merchandise trade values     ITS_MTV_QX
# 11004  Merchandise trade values     ITS_MTV_QX
# 11005  Merchandise trade values     ITS_MTV_QX
#
#                                            Indicator Reporting Economy Code  \
# 6304   Merchandise imports by product group  annual                    000
# 6305   Merchandise imports by product group  annual                    004
# 6306   Merchandise imports by product group  annual                    008
# 6307   Merchandise imports by product group  annual                    012
# 6308   Merchandise imports by product group  annual                    016
# 6309   Merchandise imports by product group  annual                    020
# 6310   Merchandise imports by product group  annual                    024
# 6311   Merchandise imports by product group  annual                    028
# 6312   Merchandise imports by product group  annual                    031
# 6313   Merchandise imports by product group  annual                    032
# 6314   Merchandise imports by product group  annual                    036
# 6315   Merchandise imports by product group  annual                    040
# 6316   Merchandise imports by product group  annual                    044
# 6317   Merchandise imports by product group  annual                    048
# 6318   Merchandise imports by product group  annual                    050
# ...                                              ...                    ...
# 10991          Total merchandise exports - quarterly                    932
# 10992          Total merchandise exports - quarterly                    932
# 10993          Total merchandise exports - quarterly                    932
# 10994          Total merchandise exports - quarterly                    949
# 10995          Total merchandise exports - quarterly                    949
# 10996          Total merchandise exports - quarterly                    949
# 10997          Total merchandise exports - quarterly                    949
# 10998          Total merchandise exports - quarterly                    949
# 10999          Total merchandise exports - quarterly                    949
# 11000          Total merchandise exports - quarterly                    970
# 11001          Total merchandise exports - quarterly                    970
# 11002          Total merchandise exports - quarterly                    970
# 11003          Total merchandise exports - quarterly                    970
# 11004          Total merchandise exports - quarterly                    970
# 11005          Total merchandise exports - quarterly                    970
#
#       Reporting Economy ISO3A Code  \
# 6304                           NaN
# 6305                           AFG
# 6306                           ALB
# 6307                           DZA
# 6308                           ASM
# 6309                           AND
# 6310                           AGO
# 6311                           ATG
# 6312                           AZE
# 6313                           ARG
# 6314                           AUS
# 6315                           AUT
# 6316                           BHS
# 6317                           BHR
# 6318                           BGD
# ...                            ...
# 10991                          NaN
# 10992                          NaN
# 10993                          NaN
# 10994                          NaN
# 10995                          NaN
# 10996                          NaN
# 10997                          NaN
# 10998                          NaN
# 10999                          NaN
# 11000                          NaN
# 11001                          NaN
# 11002                          NaN
# 11003                          NaN
# 11004                          NaN
# 11005                          NaN
#
#                                  Reporting Economy Partner Economy Code  \
# 6304                                         World                  000
# 6305                                   Afghanistan                  000
# 6306                                       Albania                  000
# 6307                                       Algeria                  000
# 6308                                American Samoa                  000
# 6309                                       Andorra                  000
# 6310                                        Angola                  000
# 6311                           Antigua and Barbuda                  000
# 6312                                    Azerbaijan                  000
# 6313                                     Argentina                  000
# 6314                                     Australia                  000
# 6315                                       Austria                  000
# 6316                                       Bahamas                  000
# 6317                           Bahrain, Kingdom of                  000
# 6318                                    Bangladesh                  000
# ...                                            ...                  ...
# 10991  South and Central America and the Caribbean                  000
# 10992  South and Central America and the Caribbean                  000
# 10993  South and Central America and the Caribbean                  000
# 10994                       Six East Asian traders                  000
# 10995                       Six East Asian traders                  000
# 10996                       Six East Asian traders                  000
# 10997                       Six East Asian traders                  000
# 10998                       Six East Asian traders                  000
# 10999                       Six East Asian traders                  000
# 11000                                         Asia                  000
# 11001                                         Asia                  000
# 11002                                         Asia                  000
# 11003                                         Asia                  000
# 11004                                         Asia                  000
# 11005                                         Asia                  000
#
#       Partner Economy ISO3A Code Partner Economy  \
# 6304                         NaN           World
# 6305                         NaN           World
# 6306                         NaN           World
# 6307                         NaN           World
# 6308                         NaN           World
# 6309                         NaN           World
# 6310                         NaN           World
# 6311                         NaN           World
# 6312                         NaN           World
# 6313                         NaN           World
# 6314                         NaN           World
# 6315                         NaN           World
# 6316                         NaN           World
# 6317                         NaN           World
# 6318                         NaN           World
# ...                          ...             ...
# 10991                        NaN           World
# 10992                        NaN           World
# 10993                        NaN           World
# 10994                        NaN           World
# 10995                        NaN           World
# 10996                        NaN           World
# 10997                        NaN           World
# 10998                        NaN           World
# 10999                        NaN           World
# 11000                        NaN           World
# 11001                        NaN           World
# 11002                        NaN           World
# 11003                        NaN           World
# 11004                        NaN           World
# 11005                        NaN           World
#
#       Product/Sector Classification Code  \
# 6304                               SITC3
# 6305                               SITC3
# 6306                               SITC3
# 6307                               SITC3
# 6308                               SITC3
# 6309                               SITC3
# 6310                               SITC3
# 6311                               SITC3
# 6312                               SITC3
# 6313                               SITC3
# 6314                               SITC3
# 6315                               SITC3
# 6316                               SITC3
# 6317                               SITC3
# 6318                               SITC3
# ...                                  ...
# 10991                              SITC3
# 10992                              SITC3
# 10993                              SITC3
# 10994                              SITC3
# 10995                              SITC3
# 10996                              SITC3
# 10997                              SITC3
# 10998                              SITC3
# 10999                              SITC3
# 11000                              SITC3
# 11001                              SITC3
# 11002                              SITC3
# 11003                              SITC3
# 11004                              SITC3
# 11005                              SITC3
#
#                     Product/Sector Classification Product/Sector Code  \
# 6304   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6305   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6306   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6307   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6308   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6309   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6310   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6311   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6312   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6313   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6314   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6315   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6316   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6317   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6318   Merchandise - SITC Revision 3 (aggregates)                  TO
# ...                                           ...                 ...
# 10991  Merchandise - SITC Revision 3 (aggregates)                  TO
# 10992  Merchandise - SITC Revision 3 (aggregates)                  TO
# 10993  Merchandise - SITC Revision 3 (aggregates)                  TO
# 10994  Merchandise - SITC Revision 3 (aggregates)                  TO
# 10995  Merchandise - SITC Revision 3 (aggregates)                  TO
# 10996  Merchandise - SITC Revision 3 (aggregates)                  TO
# 10997  Merchandise - SITC Revision 3 (aggregates)                  TO
# 10998  Merchandise - SITC Revision 3 (aggregates)                  TO
# 10999  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11000  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11001  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11002  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11003  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11004  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11005  Merchandise - SITC Revision 3 (aggregates)                  TO
#
#           Product/Sector Period Code          Period Frequency Code  \
# 6304   Total merchandise           A          Annual              A
# 6305   Total merchandise           A          Annual              A
# 6306   Total merchandise           A          Annual              A
# 6307   Total merchandise           A          Annual              A
# 6308   Total merchandise           A          Annual              A
# 6309   Total merchandise           A          Annual              A
# 6310   Total merchandise           A          Annual              A
# 6311   Total merchandise           A          Annual              A
# 6312   Total merchandise           A          Annual              A
# 6313   Total merchandise           A          Annual              A
# 6314   Total merchandise           A          Annual              A
# 6315   Total merchandise           A          Annual              A
# 6316   Total merchandise           A          Annual              A
# 6317   Total merchandise           A          Annual              A
# 6318   Total merchandise           A          Annual              A
# ...                  ...         ...             ...            ...
# 10991  Total merchandise          Q2  Second Quarter              Q
# 10992  Total merchandise          Q3   Third Quarter              Q
# 10993  Total merchandise          Q4  Fourth Quarter              Q
# 10994  Total merchandise          Q1   First Quarter              Q
# 10995  Total merchandise          Q1   First Quarter              Q
# 10996  Total merchandise          Q2  Second Quarter              Q
# 10997  Total merchandise          Q2  Second Quarter              Q
# 10998  Total merchandise          Q3   Third Quarter              Q
# 10999  Total merchandise          Q4  Fourth Quarter              Q
# 11000  Total merchandise          Q1   First Quarter              Q
# 11001  Total merchandise          Q1   First Quarter              Q
# 11002  Total merchandise          Q2  Second Quarter              Q
# 11003  Total merchandise          Q2  Second Quarter              Q
# 11004  Total merchandise          Q3   Third Quarter              Q
# 11005  Total merchandise          Q4  Fourth Quarter              Q
#
#        Frequency Unit Code               Unit  Year Value Flag Code  \
# 6304      Annual       USM  Million US dollar  2021             NaN
# 6305      Annual       USM  Million US dollar  2021               E
# 6306      Annual       USM  Million US dollar  2021             NaN
# 6307      Annual       USM  Million US dollar  2021               E
# 6308      Annual       USM  Million US dollar  2021               E
# 6309      Annual       USM  Million US dollar  2021               E
# 6310      Annual       USM  Million US dollar  2021             NaN
# 6311      Annual       USM  Million US dollar  2021             NaN
# 6312      Annual       USM  Million US dollar  2021             NaN
# 6313      Annual       USM  Million US dollar  2021             NaN
# 6314      Annual       USM  Million US dollar  2021             NaN
# 6315      Annual       USM  Million US dollar  2021             NaN
# 6316      Annual       USM  Million US dollar  2021             NaN
# 6317      Annual       USM  Million US dollar  2021             NaN
# 6318      Annual       USM  Million US dollar  2021               E
# ...          ...       ...                ...   ...             ...
# 10991  Quarterly       USM  Million US dollar  2022             NaN
# 10992  Quarterly       USM  Million US dollar  2021             NaN
# 10993  Quarterly       USM  Million US dollar  2021             NaN
# 10994  Quarterly       USM  Million US dollar  2022             NaN
# 10995  Quarterly       USM  Million US dollar  2021             NaN
# 10996  Quarterly       USM  Million US dollar  2021             NaN
# 10997  Quarterly       USM  Million US dollar  2022             NaN
# 10998  Quarterly       USM  Million US dollar  2021             NaN
# 10999  Quarterly       USM  Million US dollar  2021             NaN
# 11000  Quarterly       USM  Million US dollar  2021             NaN
# 11001  Quarterly       USM  Million US dollar  2022             NaN
# 11002  Quarterly       USM  Million US dollar  2022             NaN
# 11003  Quarterly       USM  Million US dollar  2021             NaN
# 11004  Quarterly       USM  Million US dollar  2021             NaN
# 11005  Quarterly       USM  Million US dollar  2021             NaN
#
#       Value Flag  Text Value         Value
# 6304         NaN         NaN  2.258658e+07
# 6305    Estimate         NaN  5.574000e+03
# 6306         NaN         NaN  7.718084e+03
# 6307    Estimate         NaN  3.600000e+04
# 6308    Estimate         NaN  7.110000e+02
# 6309    Estimate         NaN  1.822574e+03
# 6310         NaN         NaN  1.179485e+04
# 6311         NaN         NaN  5.955260e+02
# 6312         NaN         NaN  1.170580e+04
# 6313         NaN         NaN  6.318500e+04
# 6314         NaN         NaN  2.611648e+05
# 6315         NaN         NaN  2.195198e+05
# 6316         NaN         NaN  3.201300e+03
# 6317         NaN         NaN  1.418762e+04
# 6318    Estimate         NaN  8.044800e+04
# ...          ...         ...           ...
# 10991        NaN         NaN  2.225239e+05
# 10992        NaN         NaN  1.899798e+05
# 10993        NaN         NaN  1.825518e+05
# 10994        NaN         NaN  5.793900e+05
# 10995        NaN         NaN  4.913800e+05
# 10996        NaN         NaN  5.245346e+05
# 10997        NaN         NaN  6.058231e+05
# 10998        NaN         NaN  5.407289e+05
# 10999        NaN         NaN  5.840582e+05
# 11000        NaN         NaN  1.887080e+06
# 11001        NaN         NaN  2.185884e+06
# 11002        NaN         NaN  2.349788e+06
# 11003        NaN         NaN  2.065571e+06
# 11004        NaN         NaN  2.188447e+06
# 11005        NaN         NaN  2.369557e+06
#
# [4702 rows x 24 columns]

# %%
serv_comerc_df_ic = tabela_bruta_comercio_internacional.loc[tabela_bruta_comercio_internacional['Indicator Category'] == str(lista_categorias[2])]
serv_comerc_df_ic
# Out:
#                  Indicator Category Indicator Code  \
# 11006  Trade in commercial services     ITS_CS_AM6
# 11007  Trade in commercial services     ITS_CS_AM6
# 11008  Trade in commercial services     ITS_CS_AM6
# 11009  Trade in commercial services     ITS_CS_AM6
# 11010  Trade in commercial services     ITS_CS_AM6
# 11011  Trade in commercial services     ITS_CS_AM6
# 11012  Trade in commercial services     ITS_CS_AM6
# 11013  Trade in commercial services     ITS_CS_AM6
# 11014  Trade in commercial services     ITS_CS_AM6
# 11015  Trade in commercial services     ITS_CS_AM6
# 11016  Trade in commercial services     ITS_CS_AM6
# 11017  Trade in commercial services     ITS_CS_AM6
# 11018  Trade in commercial services     ITS_CS_AM6
# 11019  Trade in commercial services     ITS_CS_AM6
# 11020  Trade in commercial services     ITS_CS_AM6
# ...                             ...            ...
# 97649  Trade in commercial services      ITS_CS_QX
# 97650  Trade in commercial services      ITS_CS_QX
# 97651  Trade in commercial services      ITS_CS_QX
# 97652  Trade in commercial services      ITS_CS_QX
# 97653  Trade in commercial services      ITS_CS_QX
# 97654  Trade in commercial services      ITS_CS_QX
# 97655  Trade in commercial services      ITS_CS_QX
# 97656  Trade in commercial services      ITS_CS_QX
# 97657  Trade in commercial services      ITS_CS_QX
# 97658  Trade in commercial services      ITS_CS_QX
# 97659  Trade in commercial services      ITS_CS_QX
# 97660  Trade in commercial services      ITS_CS_QX
# 97661  Trade in commercial services      ITS_CS_QX
# 97662  Trade in commercial services      ITS_CS_QX
# 97663  Trade in commercial services      ITS_CS_QX
#
#                                                         Indicator  \
# 11006  Commercial services imports by sector and partner  annual
# 11007  Commercial services imports by sector and partner  annual
# 11008  Commercial services imports by sector and partner  annual
# 11009  Commercial services imports by sector and partner  annual
# 11010  Commercial services imports by sector and partner  annual
# 11011  Commercial services imports by sector and partner  annual
# 11012  Commercial services imports by sector and partner  annual
# 11013  Commercial services imports by sector and partner  annual
# 11014  Commercial services imports by sector and partner  annual
# 11015  Commercial services imports by sector and partner  annual
# 11016  Commercial services imports by sector and partner  annual
# 11017  Commercial services imports by sector and partner  annual
# 11018  Commercial services imports by sector and partner  annual
# 11019  Commercial services imports by sector and partner  annual
# 11020  Commercial services imports by sector and partner  annual
# ...                                                           ...
# 97649      Commercial services exports by main sector  quarterly
# 97650      Commercial services exports by main sector  quarterly
# 97651      Commercial services exports by main sector  quarterly
# 97652      Commercial services exports by main sector  quarterly
# 97653      Commercial services exports by main sector  quarterly
# 97654      Commercial services exports by main sector  quarterly
# 97655      Commercial services exports by main sector  quarterly
# 97656      Commercial services exports by main sector  quarterly
# 97657      Commercial services exports by main sector  quarterly
# 97658      Commercial services exports by main sector  quarterly
# 97659      Commercial services exports by main sector  quarterly
# 97660      Commercial services exports by main sector  quarterly
# 97661      Commercial services exports by main sector  quarterly
# 97662      Commercial services exports by main sector  quarterly
# 97663      Commercial services exports by main sector  quarterly
#
#       Reporting Economy Code Reporting Economy ISO3A Code Reporting Economy  \
# 11006                    000                          NaN             World
# 11007                    000                          NaN             World
# 11008                    000                          NaN             World
# 11009                    000                          NaN             World
# 11010                    000                          NaN             World
# 11011                    000                          NaN             World
# 11012                    000                          NaN             World
# 11013                    000                          NaN             World
# 11014                    000                          NaN             World
# 11015                    000                          NaN             World
# 11016                    000                          NaN             World
# 11017                    000                          NaN             World
# 11018                    000                          NaN             World
# 11019                    000                          NaN             World
# 11020                    000                          NaN             World
# ...                      ...                          ...               ...
# 97649                    927                          NaN    Euro Area (19)
# 97650                    927                          NaN    Euro Area (19)
# 97651                    927                          NaN    Euro Area (19)
# 97652                    927                          NaN    Euro Area (19)
# 97653                    927                          NaN    Euro Area (19)
# 97654                    927                          NaN    Euro Area (19)
# 97655                    927                          NaN    Euro Area (19)
# 97656                    927                          NaN    Euro Area (19)
# 97657                    927                          NaN    Euro Area (19)
# 97658                    927                          NaN    Euro Area (19)
# 97659                    927                          NaN    Euro Area (19)
# 97660                    927                          NaN    Euro Area (19)
# 97661                    927                          NaN    Euro Area (19)
# 97662                    927                          NaN    Euro Area (19)
# 97663                    927                          NaN    Euro Area (19)
#
#       Partner Economy Code Partner Economy ISO3A Code  \
# 11006                  000                        NaN
# 11007                  000                        NaN
# 11008                  000                        NaN
# 11009                  000                        NaN
# 11010                  000                        NaN
# 11011                  000                        NaN
# 11012                  000                        NaN
# 11013                  000                        NaN
# 11014                  000                        NaN
# 11015                  000                        NaN
# 11016                  000                        NaN
# 11017                  000                        NaN
# 11018                  000                        NaN
# 11019                  000                        NaN
# 11020                  000                        NaN
# ...                    ...                        ...
# 97649                  ZX9                        NaN
# 97650                  ZX9                        NaN
# 97651                  ZX9                        NaN
# 97652                  ZX9                        NaN
# 97653                  ZX9                        NaN
# 97654                  ZX9                        NaN
# 97655                  ZX9                        NaN
# 97656                  ZX9                        NaN
# 97657                  ZX9                        NaN
# 97658                  ZX9                        NaN
# 97659                  ZX9                        NaN
# 97660                  ZX9                        NaN
# 97661                  ZX9                        NaN
# 97662                  ZX9                        NaN
# 97663                  ZX9                        NaN
#
#                   Partner Economy Product/Sector Classification Code  \
# 11006                       World                               BOP6
# 11007                       World                               BOP6
# 11008                       World                               BOP6
# 11009                       World                               BOP6
# 11010                       World                               BOP6
# 11011                       World                               BOP6
# 11012                       World                               BOP6
# 11013                       World                               BOP6
# 11014                       World                               BOP6
# 11015                       World                               BOP6
# 11016                       World                               BOP6
# 11017                       World                               BOP6
# 11018                       World                               BOP6
# 11019                       World                               BOP6
# 11020                       World                               BOP6
# ...                           ...                                ...
# 97649  Extra Euro Area (19) Trade                               BOP6
# 97650  Extra Euro Area (19) Trade                               BOP6
# 97651  Extra Euro Area (19) Trade                               BOP6
# 97652  Extra Euro Area (19) Trade                               BOP6
# 97653  Extra Euro Area (19) Trade                               BOP6
# 97654  Extra Euro Area (19) Trade                               BOP6
# 97655  Extra Euro Area (19) Trade                               BOP6
# 97656  Extra Euro Area (19) Trade                               BOP6
# 97657  Extra Euro Area (19) Trade                               BOP6
# 97658  Extra Euro Area (19) Trade                               BOP6
# 97659  Extra Euro Area (19) Trade                               BOP6
# 97660  Extra Euro Area (19) Trade                               BOP6
# 97661  Extra Euro Area (19) Trade                               BOP6
# 97662  Extra Euro Area (19) Trade                               BOP6
# 97663  Extra Euro Area (19) Trade                               BOP6
#
#                                              Product/Sector Classification  \
# 11006  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11007  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11008  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11009  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11010  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11011  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11012  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11013  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11014  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11015  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11016  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11017  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11018  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11019  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11020  Services - Extended Balance of Payments Classification (EBOPS 2010)
# ...                                                                    ...
# 97649  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97650  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97651  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97652  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97653  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97654  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97655  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97656  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97657  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97658  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97659  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97660  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97661  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97662  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97663  Services - Extended Balance of Payments Classification (EBOPS 2010)
#
#       Product/Sector Code               Product/Sector Period Code  \
# 11006                   S    Memo item: Total services           A
# 11007                  SC                    Transport           A
# 11008                 SC1                Sea transport           A
# 11009                SC11              Passenger (Sea)           A
# 11010                SC12                Freight (Sea)           A
# 11011                SC13                  Other (Sea)           A
# 11012                 SC2                Air transport           A
# 11013                SC21              Passenger (Air)           A
# 11014                SC22                Freight (Air)           A
# 11015                SC23                  Other (Air)           A
# 11016                 SC3     Other modes of transport           A
# 11017                SC31            Passenger (Other)           A
# 11018                SC32              Freight (Other)           A
# 11019                SC33                Other (Other)           A
# 11020                 SC4  Postal and courier services           A
# ...                   ...                          ...         ...
# 97649                SOX1    Other commercial services          Q1
# 97650                SOX1    Other commercial services          Q1
# 97651                SOX1    Other commercial services          Q2
# 97652                SOX1    Other commercial services          Q3
# 97653                SOX1    Other commercial services          Q4
# 97654                SPX1    Memo item: Other services          Q1
# 97655                SPX1    Memo item: Other services          Q1
# 97656                SPX1    Memo item: Other services          Q2
# 97657                SPX1    Memo item: Other services          Q3
# 97658                SPX1    Memo item: Other services          Q4
# 97659                SPX4       Goods-related services          Q1
# 97660                SPX4       Goods-related services          Q1
# 97661                SPX4       Goods-related services          Q2
# 97662                SPX4       Goods-related services          Q3
# 97663                SPX4       Goods-related services          Q4
#
#                Period Frequency Code  Frequency Unit Code               Unit  \
# 11006          Annual              A     Annual       USM  Million US dollar
# 11007          Annual              A     Annual       USM  Million US dollar
# 11008          Annual              A     Annual       USM  Million US dollar
# 11009          Annual              A     Annual       USM  Million US dollar
# 11010          Annual              A     Annual       USM  Million US dollar
# 11011          Annual              A     Annual       USM  Million US dollar
# 11012          Annual              A     Annual       USM  Million US dollar
# 11013          Annual              A     Annual       USM  Million US dollar
# 11014          Annual              A     Annual       USM  Million US dollar
# 11015          Annual              A     Annual       USM  Million US dollar
# 11016          Annual              A     Annual       USM  Million US dollar
# 11017          Annual              A     Annual       USM  Million US dollar
# 11018          Annual              A     Annual       USM  Million US dollar
# 11019          Annual              A     Annual       USM  Million US dollar
# 11020          Annual              A     Annual       USM  Million US dollar
# ...               ...            ...        ...       ...                ...
# 97649   First Quarter              Q  Quarterly       USM  Million US dollar
# 97650   First Quarter              Q  Quarterly       USM  Million US dollar
# 97651  Second Quarter              Q  Quarterly       USM  Million US dollar
# 97652   Third Quarter              Q  Quarterly       USM  Million US dollar
# 97653  Fourth Quarter              Q  Quarterly       USM  Million US dollar
# 97654   First Quarter              Q  Quarterly       USM  Million US dollar
# 97655   First Quarter              Q  Quarterly       USM  Million US dollar
# 97656  Second Quarter              Q  Quarterly       USM  Million US dollar
# 97657   Third Quarter              Q  Quarterly       USM  Million US dollar
# 97658  Fourth Quarter              Q  Quarterly       USM  Million US dollar
# 97659   First Quarter              Q  Quarterly       USM  Million US dollar
# 97660   First Quarter              Q  Quarterly       USM  Million US dollar
# 97661  Second Quarter              Q  Quarterly       USM  Million US dollar
# 97662   Third Quarter              Q  Quarterly       USM  Million US dollar
# 97663  Fourth Quarter              Q  Quarterly       USM  Million US dollar
#
#        Year Value Flag Code Value Flag  Text Value         Value
# 11006  2021             NaN        NaN         NaN  5.623458e+06
# 11007  2021             NaN        NaN         NaN  1.374130e+06
# 11008  2021             NaN        NaN         NaN  7.043807e+05
# 11009  2021             NaN        NaN         NaN  2.213825e+04
# 11010  2021             NaN        NaN         NaN  5.446202e+05
# 11011  2021             NaN        NaN         NaN  1.374465e+05
# 11012  2021             NaN        NaN         NaN  3.295371e+05
# 11013  2021             NaN        NaN         NaN  9.850616e+04
# 11014  2021             NaN        NaN         NaN  1.563009e+05
# 11015  2021             NaN        NaN         NaN  7.470746e+04
# 11016  2021             NaN        NaN         NaN  3.129454e+05
# 11017  2021             NaN        NaN         NaN  7.068957e+03
# 11018  2021             NaN        NaN         NaN  2.197735e+05
# 11019  2021             NaN        NaN         NaN  8.609978e+04
# 11020  2021             NaN        NaN         NaN  2.662472e+04
# ...     ...             ...        ...         ...           ...
# 97649  2022             NaN        NaN         NaN  2.035027e+05
# 97650  2021             NaN        NaN         NaN  1.878851e+05
# 97651  2021             NaN        NaN         NaN  2.031896e+05
# 97652  2021             NaN        NaN         NaN  2.054245e+05
# 97653  2021             NaN        NaN         NaN  2.294427e+05
# 97654  2022             NaN        NaN         NaN  2.069889e+05
# 97655  2021             NaN        NaN         NaN  1.910370e+05
# 97656  2021             NaN        NaN         NaN  2.066432e+05
# 97657  2021             NaN        NaN         NaN  2.090717e+05
# 97658  2021             NaN        NaN         NaN  2.331683e+05
# 97659  2022             NaN        NaN         NaN  1.531211e+04
# 97660  2021             NaN        NaN         NaN  1.333043e+04
# 97661  2021             NaN        NaN         NaN  1.360313e+04
# 97662  2021             NaN        NaN         NaN  1.317543e+04
# 97663  2021             NaN        NaN         NaN  1.560341e+04
#
# [86658 rows x 24 columns]

# %%
lista_tipos_indices_repet = index_df_ic['Indicator'].tolist()
lista_tipos_indices = []
[lista_tipos_indices.append(indice) for indice in lista_tipos_indices_repet if indice not in lista_tipos_indices]
print(lista_tipos_indices)
# Out:
# ['Merchandise import value chained indices - annual', 'Merchandise import value fixed-base indices - annual', 'Merchandise import volume chained indices - annual', 'Merchandise import volume fixed-base indices - annual', 'Merchandise import volume change - annual', 'Merchandise import unit value chained indices - annual', 'Merchandise import unit value fixed-base indices - annual', 'Merchandise export unit value chained indices - annual', 'Merchandise export unit value fixed-base indices - annual', 'Merchandise export value chained indices - annual', 'Merchandise export value fixed-base indices - annual', 'Merchandise export volume chained indices - annual', 'Merchandise export volume fixed-base indices - annual', 'Merchandise export volume change - annual', 'Import price changes of manufactured goods - monthly', 'Import price indices of manufactured goods - monthly', 'Export price changes of manufactured goods - monthly', 'Export price indices of manufactured goods - monthly', 'Merchandise import volume indices, not seasonally adjusted - quarterly', 'Merchandise import volume indices, seasonally adjusted - quarterly', 'Merchandise export volume indices, not seasonally adjusted - quarterly', 'Merchandise export volume indices, seasonally adjusted - quarterly']

# %%
lista_ind_valores_comerc_repet = values_df_ic['Indicator'].tolist()
lista_ind_valores_comerc = []
[lista_ind_valores_comerc.append(critério) for critério in lista_ind_valores_comerc_repet if critério not in lista_ind_valores_comerc]
print(lista_ind_valores_comerc)
# Out:
# ['Merchandise imports by product group \x96 annual', 'Merchandise exports by product group \x96 annual', 'Total merchandise imports - monthly', 'Total merchandise exports - monthly', 'Total merchandise imports - quarterly', 'Total merchandise exports - quarterly']

# %%
lista_cs_ind_rep = serv_comerc_df_ic['Indicator'].tolist()
lista_cs_ind = []
[lista_cs_ind.append(critério) for critério in lista_cs_ind_rep if critério not in lista_cs_ind]
print(lista_cs_ind)
# Out:
# ['Commercial services imports by sector and partner \x96 annual', 'Commercial services exports by sector and partner \x96 annual', 'Commercial services imports of selected economies \x96 monthly', 'Commercial services imports of selected economies (growth) \x96 monthly', 'Commercial services exports of selected economies \x96 monthly', 'Commercial services exports of selected economies (growth) \x96 monthly', 'Commercial services imports by main sector \x96 quarterly', 'Commercial services exports by main sector \x96 quarterly']

# %%
print('indicadores de índice: ',len(lista_tipos_indices))
print('indicadores de valores comerciais: ',len(lista_ind_valores_comerc))
print('indicadores de serviços comerciais: ',len(lista_cs_ind))
# Out:
# indicadores de índice:  22
# indicadores de valores comerciais:  6
# indicadores de serviços comerciais:  8
