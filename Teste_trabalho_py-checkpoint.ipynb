# %%
#importando as bibliotecas necessárias para acessar o diretório e trabalhar os dados (antes da construção de gráficos)

import os
import pandas as pd

# %%
#mudando o diretório para onde se encontra o arquivo

print('Diretório inicial: {}'.format(os.getcwd()))
os.chdir('C:/Users/ppomp/Documents/Python')
# Out:
# Diretório inicial: C:\Users\ppomp

# %%
#verificando se deu certo

print('novo diretório: {}'.format(os.getcwd()))
# Out:
# novo diretório: C:\Users\ppomp\Documents\Python

# %%
#lendo o arquivo como Data Frame

tabela_bruta_comercio_internacional = pd.read_csv('WTD_trabalho.py.csv', sep = ',',  encoding = 'ISO-8859-1')
# Out:
# C:\Users\ppomp\AppData\Local\Temp\ipykernel_17536\1575459810.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_bruta_comercio_internacional = pd.read_csv('WTD_trabalho.py.csv', sep = ',',  encoding = 'ISO-8859-1')

# %%
#aumentar número de linhas e colunas visualizáveis para ter um entendimento melhor da base d 
pd.options.display.max_rows = 30
pd.options.display.max_columns = 24
pd.options.display.max_colwidth = 100

tabela_bruta_comercio_internacional
# Out:
#                            Indicator Category Indicator Code  \
# 0      Merchandise trade - indices and prices     ITS_MTP_AM
# 1      Merchandise trade - indices and prices     ITS_MTP_AM
# 2      Merchandise trade - indices and prices     ITS_MTP_AM
# 3      Merchandise trade - indices and prices     ITS_MTP_AM
# 4      Merchandise trade - indices and prices     ITS_MTP_AM
# ...                                       ...            ...
# 97659            Trade in commercial services      ITS_CS_QX
# 97660            Trade in commercial services      ITS_CS_QX
# 97661            Trade in commercial services      ITS_CS_QX
# 97662            Trade in commercial services      ITS_CS_QX
# 97663            Trade in commercial services      ITS_CS_QX
#
#                                                     Indicator  \
# 0           Merchandise import value chained indices - annual
# 1           Merchandise import value chained indices - annual
# 2           Merchandise import value chained indices - annual
# 3           Merchandise import value chained indices - annual
# 4           Merchandise import value chained indices - annual
# ...                                                       ...
# 97659  Commercial services exports by main sector  quarterly
# 97660  Commercial services exports by main sector  quarterly
# 97661  Commercial services exports by main sector  quarterly
# 97662  Commercial services exports by main sector  quarterly
# 97663  Commercial services exports by main sector  quarterly
#
#       Reporting Economy Code Reporting Economy ISO3A Code Reporting Economy  \
# 0                        000                          NaN             World
# 1                        004                          AFG       Afghanistan
# 2                        008                          ALB           Albania
# 3                        012                          DZA           Algeria
# 4                        016                          ASM    American Samoa
# ...                      ...                          ...               ...
# 97659                    927                          NaN    Euro Area (19)
# 97660                    927                          NaN    Euro Area (19)
# 97661                    927                          NaN    Euro Area (19)
# 97662                    927                          NaN    Euro Area (19)
# 97663                    927                          NaN    Euro Area (19)
#
#       Partner Economy Code Partner Economy ISO3A Code  \
# 0                      000                        NaN
# 1                      000                        NaN
# 2                      000                        NaN
# 3                      000                        NaN
# 4                      000                        NaN
# ...                    ...                        ...
# 97659                  ZX9                        NaN
# 97660                  ZX9                        NaN
# 97661                  ZX9                        NaN
# 97662                  ZX9                        NaN
# 97663                  ZX9                        NaN
#
#                   Partner Economy Product/Sector Classification Code  \
# 0                           World                              SITC3
# 1                           World                              SITC3
# 2                           World                              SITC3
# 3                           World                              SITC3
# 4                           World                              SITC3
# ...                           ...                                ...
# 97659  Extra Euro Area (19) Trade                               BOP6
# 97660  Extra Euro Area (19) Trade                               BOP6
# 97661  Extra Euro Area (19) Trade                               BOP6
# 97662  Extra Euro Area (19) Trade                               BOP6
# 97663  Extra Euro Area (19) Trade                               BOP6
#
#                                              Product/Sector Classification  \
# 0                               Merchandise - SITC Revision 3 (aggregates)
# 1                               Merchandise - SITC Revision 3 (aggregates)
# 2                               Merchandise - SITC Revision 3 (aggregates)
# 3                               Merchandise - SITC Revision 3 (aggregates)
# 4                               Merchandise - SITC Revision 3 (aggregates)
# ...                                                                    ...
# 97659  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97660  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97661  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97662  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97663  Services - Extended Balance of Payments Classification (EBOPS 2010)
#
#       Product/Sector Code          Product/Sector Period Code          Period  \
# 0                      TO       Total merchandise           A          Annual
# 1                      TO       Total merchandise           A          Annual
# 2                      TO       Total merchandise           A          Annual
# 3                      TO       Total merchandise           A          Annual
# 4                      TO       Total merchandise           A          Annual
# ...                   ...                     ...         ...             ...
# 97659                SPX4  Goods-related services          Q1   First Quarter
# 97660                SPX4  Goods-related services          Q1   First Quarter
# 97661                SPX4  Goods-related services          Q2  Second Quarter
# 97662                SPX4  Goods-related services          Q3   Third Quarter
# 97663                SPX4  Goods-related services          Q4  Fourth Quarter
#
#       Frequency Code  Frequency Unit Code               Unit  Year  \
# 0                  A     Annual       IDP  Previous year=100  2021
# 1                  A     Annual       IDP  Previous year=100  2021
# 2                  A     Annual       IDP  Previous year=100  2021
# 3                  A     Annual       IDP  Previous year=100  2021
# 4                  A     Annual       IDP  Previous year=100  2021
# ...              ...        ...       ...                ...   ...
# 97659              Q  Quarterly       USM  Million US dollar  2022
# 97660              Q  Quarterly       USM  Million US dollar  2021
# 97661              Q  Quarterly       USM  Million US dollar  2021
# 97662              Q  Quarterly       USM  Million US dollar  2021
# 97663              Q  Quarterly       USM  Million US dollar  2021
#
#       Value Flag Code Value Flag  Text Value         Value
# 0                 NaN        NaN         NaN    126.432000
# 1                   E   Estimate         NaN     85.260000
# 2                 NaN        NaN         NaN    138.571000
# 3                   E   Estimate         NaN    104.676000
# 4                   E   Estimate         NaN    101.862000
# ...               ...        ...         ...           ...
# 97659             NaN        NaN         NaN  15312.113403
# 97660             NaN        NaN         NaN  13330.434057
# 97661             NaN        NaN         NaN  13603.131178
# 97662             NaN        NaN         NaN  13175.430665
# 97663             NaN        NaN         NaN  15603.408962
#
# [97664 rows x 24 columns]

# %%
##### criar uma lista com os nomes do todas as colunas para ter um acesso rápido a tais informações
cabeçalho = list(tabela_bruta_comercio_internacional.columns.values)
print(cabeçalho)

#analisando a tabela, ficoou claro que ela mistura diferentes tipos de informações, para lidar com isso,
#criar lista de categorias, com o intuito de dividir o data frame em vários outros para cada categoria,
#obtendo, assim, informações mais úteis

#para tanto, transformar a primeira coluna em uma lista
lista_categorias_repetidos = tabela_bruta_comercio_internacional['Indicator Category'].tolist()

#os dados repetidos e o excesso de linhas torna difícil se aproveitar da lista
#eliminar elementos repetidos com list comp.
lista_categorias = []
[lista_categorias.append(categoria) for categoria in lista_categorias_repetidos if categoria not in lista_categorias]
print(lista_categorias)
# Out:
# ['Indicator Category', 'Indicator Code', 'Indicator', 'Reporting Economy Code', 'Reporting Economy ISO3A Code', 'Reporting Economy', 'Partner Economy Code', 'Partner Economy ISO3A Code', 'Partner Economy', 'Product/Sector Classification Code', 'Product/Sector Classification', 'Product/Sector Code', 'Product/Sector', 'Period Code', 'Period', 'Frequency Code', 'Frequency', 'Unit Code', 'Unit', 'Year', 'Value Flag Code', 'Value Flag', 'Text Value', 'Value']
# ['Merchandise trade - indices and prices', 'Merchandise trade values', 'Trade in commercial services']

# %%
#tendo as categorias, usar df.loc para construir tabelas separadas de cada categoria

index_df_ic = tabela_bruta_comercio_internacional.loc[tabela_bruta_comercio_internacional['Indicator Category'] == str(lista_categorias[0])]
index_df_ic
# Out:
#                           Indicator Category Indicator Code  \
# 0     Merchandise trade - indices and prices     ITS_MTP_AM
# 1     Merchandise trade - indices and prices     ITS_MTP_AM
# 2     Merchandise trade - indices and prices     ITS_MTP_AM
# 3     Merchandise trade - indices and prices     ITS_MTP_AM
# 4     Merchandise trade - indices and prices     ITS_MTP_AM
# ...                                      ...            ...
# 6299  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6300  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6301  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6302  Merchandise trade - indices and prices  ITS_MTP_QXVSA
# 6303  Merchandise trade - indices and prices  ITS_MTP_QXVSA
#
#                                                                Indicator  \
# 0                      Merchandise import value chained indices - annual
# 1                      Merchandise import value chained indices - annual
# 2                      Merchandise import value chained indices - annual
# 3                      Merchandise import value chained indices - annual
# 4                      Merchandise import value chained indices - annual
# ...                                                                  ...
# 6299  Merchandise export volume indices, seasonally adjusted - quarterly
# 6300  Merchandise export volume indices, seasonally adjusted - quarterly
# 6301  Merchandise export volume indices, seasonally adjusted - quarterly
# 6302  Merchandise export volume indices, seasonally adjusted - quarterly
# 6303  Merchandise export volume indices, seasonally adjusted - quarterly
#
#      Reporting Economy Code Reporting Economy ISO3A Code  \
# 0                       000                          NaN
# 1                       004                          AFG
# 2                       008                          ALB
# 3                       012                          DZA
# 4                       016                          ASM
# ...                     ...                          ...
# 6299                    997                          NaN
# 6300                    997                          NaN
# 6301                    997                          NaN
# 6302                    997                          NaN
# 6303                    997                          NaN
#
#               Reporting Economy Partner Economy Code  \
# 0                         World                  000
# 1                   Afghanistan                  000
# 2                       Albania                  000
# 3                       Algeria                  000
# 4                American Samoa                  000
# ...                         ...                  ...
# 6299  Least-developed countries                  000
# 6300  Least-developed countries                  000
# 6301  Least-developed countries                  000
# 6302  Least-developed countries                  000
# 6303  Least-developed countries                  000
#
#      Partner Economy ISO3A Code Partner Economy  \
# 0                           NaN           World
# 1                           NaN           World
# 2                           NaN           World
# 3                           NaN           World
# 4                           NaN           World
# ...                         ...             ...
# 6299                        NaN           World
# 6300                        NaN           World
# 6301                        NaN           World
# 6302                        NaN           World
# 6303                        NaN           World
#
#      Product/Sector Classification Code  \
# 0                                 SITC3
# 1                                 SITC3
# 2                                 SITC3
# 3                                 SITC3
# 4                                 SITC3
# ...                                 ...
# 6299                              SITC3
# 6300                              SITC3
# 6301                              SITC3
# 6302                              SITC3
# 6303                              SITC3
#
#                    Product/Sector Classification Product/Sector Code  \
# 0     Merchandise - SITC Revision 3 (aggregates)                  TO
# 1     Merchandise - SITC Revision 3 (aggregates)                  TO
# 2     Merchandise - SITC Revision 3 (aggregates)                  TO
# 3     Merchandise - SITC Revision 3 (aggregates)                  TO
# 4     Merchandise - SITC Revision 3 (aggregates)                  TO
# ...                                          ...                 ...
# 6299  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6300  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6301  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6302  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6303  Merchandise - SITC Revision 3 (aggregates)                  TO
#
#          Product/Sector Period Code          Period Frequency Code  Frequency  \
# 0     Total merchandise           A          Annual              A     Annual
# 1     Total merchandise           A          Annual              A     Annual
# 2     Total merchandise           A          Annual              A     Annual
# 3     Total merchandise           A          Annual              A     Annual
# 4     Total merchandise           A          Annual              A     Annual
# ...                 ...         ...             ...            ...        ...
# 6299  Total merchandise          Q1   First Quarter              Q  Quarterly
# 6300  Total merchandise          Q2  Second Quarter              Q  Quarterly
# 6301  Total merchandise          Q2  Second Quarter              Q  Quarterly
# 6302  Total merchandise          Q3   Third Quarter              Q  Quarterly
# 6303  Total merchandise          Q4  Fourth Quarter              Q  Quarterly
#
#      Unit Code               Unit  Year Value Flag Code Value Flag  \
# 0          IDP  Previous year=100  2021             NaN        NaN
# 1          IDP  Previous year=100  2021               E   Estimate
# 2          IDP  Previous year=100  2021             NaN        NaN
# 3          IDP  Previous year=100  2021               E   Estimate
# 4          IDP  Previous year=100  2021               E   Estimate
# ...        ...                ...   ...             ...        ...
# 6299    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6300    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6301    ID05Q1         2005Q1=100  2022             NaN        NaN
# 6302    ID05Q1         2005Q1=100  2021             NaN        NaN
# 6303    ID05Q1         2005Q1=100  2021             NaN        NaN
#
#       Text Value    Value
# 0            NaN  126.432
# 1            NaN   85.260
# 2            NaN  138.571
# 3            NaN  104.676
# 4            NaN  101.862
# ...          ...      ...
# 6299         NaN  195.518
# 6300         NaN  198.815
# 6301         NaN  241.494
# 6302         NaN  196.402
# 6303         NaN  213.508
#
# [6304 rows x 24 columns]

# %%
values_df_ic = tabela_bruta_comercio_internacional.loc[tabela_bruta_comercio_internacional['Indicator Category'] == str(lista_categorias[1])]
values_df_ic
# Out:
#              Indicator Category Indicator Code  \
# 6304   Merchandise trade values     ITS_MTV_AM
# 6305   Merchandise trade values     ITS_MTV_AM
# 6306   Merchandise trade values     ITS_MTV_AM
# 6307   Merchandise trade values     ITS_MTV_AM
# 6308   Merchandise trade values     ITS_MTV_AM
# ...                         ...            ...
# 11001  Merchandise trade values     ITS_MTV_QX
# 11002  Merchandise trade values     ITS_MTV_QX
# 11003  Merchandise trade values     ITS_MTV_QX
# 11004  Merchandise trade values     ITS_MTV_QX
# 11005  Merchandise trade values     ITS_MTV_QX
#
#                                            Indicator Reporting Economy Code  \
# 6304   Merchandise imports by product group  annual                    000
# 6305   Merchandise imports by product group  annual                    004
# 6306   Merchandise imports by product group  annual                    008
# 6307   Merchandise imports by product group  annual                    012
# 6308   Merchandise imports by product group  annual                    016
# ...                                              ...                    ...
# 11001          Total merchandise exports - quarterly                    970
# 11002          Total merchandise exports - quarterly                    970
# 11003          Total merchandise exports - quarterly                    970
# 11004          Total merchandise exports - quarterly                    970
# 11005          Total merchandise exports - quarterly                    970
#
#       Reporting Economy ISO3A Code Reporting Economy Partner Economy Code  \
# 6304                           NaN             World                  000
# 6305                           AFG       Afghanistan                  000
# 6306                           ALB           Albania                  000
# 6307                           DZA           Algeria                  000
# 6308                           ASM    American Samoa                  000
# ...                            ...               ...                  ...
# 11001                          NaN              Asia                  000
# 11002                          NaN              Asia                  000
# 11003                          NaN              Asia                  000
# 11004                          NaN              Asia                  000
# 11005                          NaN              Asia                  000
#
#       Partner Economy ISO3A Code Partner Economy  \
# 6304                         NaN           World
# 6305                         NaN           World
# 6306                         NaN           World
# 6307                         NaN           World
# 6308                         NaN           World
# ...                          ...             ...
# 11001                        NaN           World
# 11002                        NaN           World
# 11003                        NaN           World
# 11004                        NaN           World
# 11005                        NaN           World
#
#       Product/Sector Classification Code  \
# 6304                               SITC3
# 6305                               SITC3
# 6306                               SITC3
# 6307                               SITC3
# 6308                               SITC3
# ...                                  ...
# 11001                              SITC3
# 11002                              SITC3
# 11003                              SITC3
# 11004                              SITC3
# 11005                              SITC3
#
#                     Product/Sector Classification Product/Sector Code  \
# 6304   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6305   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6306   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6307   Merchandise - SITC Revision 3 (aggregates)                  TO
# 6308   Merchandise - SITC Revision 3 (aggregates)                  TO
# ...                                           ...                 ...
# 11001  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11002  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11003  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11004  Merchandise - SITC Revision 3 (aggregates)                  TO
# 11005  Merchandise - SITC Revision 3 (aggregates)                  TO
#
#           Product/Sector Period Code          Period Frequency Code  \
# 6304   Total merchandise           A          Annual              A
# 6305   Total merchandise           A          Annual              A
# 6306   Total merchandise           A          Annual              A
# 6307   Total merchandise           A          Annual              A
# 6308   Total merchandise           A          Annual              A
# ...                  ...         ...             ...            ...
# 11001  Total merchandise          Q1   First Quarter              Q
# 11002  Total merchandise          Q2  Second Quarter              Q
# 11003  Total merchandise          Q2  Second Quarter              Q
# 11004  Total merchandise          Q3   Third Quarter              Q
# 11005  Total merchandise          Q4  Fourth Quarter              Q
#
#        Frequency Unit Code               Unit  Year Value Flag Code  \
# 6304      Annual       USM  Million US dollar  2021             NaN
# 6305      Annual       USM  Million US dollar  2021               E
# 6306      Annual       USM  Million US dollar  2021             NaN
# 6307      Annual       USM  Million US dollar  2021               E
# 6308      Annual       USM  Million US dollar  2021               E
# ...          ...       ...                ...   ...             ...
# 11001  Quarterly       USM  Million US dollar  2022             NaN
# 11002  Quarterly       USM  Million US dollar  2022             NaN
# 11003  Quarterly       USM  Million US dollar  2021             NaN
# 11004  Quarterly       USM  Million US dollar  2021             NaN
# 11005  Quarterly       USM  Million US dollar  2021             NaN
#
#       Value Flag  Text Value         Value
# 6304         NaN         NaN  2.258658e+07
# 6305    Estimate         NaN  5.574000e+03
# 6306         NaN         NaN  7.718084e+03
# 6307    Estimate         NaN  3.600000e+04
# 6308    Estimate         NaN  7.110000e+02
# ...          ...         ...           ...
# 11001        NaN         NaN  2.185884e+06
# 11002        NaN         NaN  2.349788e+06
# 11003        NaN         NaN  2.065571e+06
# 11004        NaN         NaN  2.188447e+06
# 11005        NaN         NaN  2.369557e+06
#
# [4702 rows x 24 columns]

# %%
serv_comerc_df_ic = tabela_bruta_comercio_internacional.loc[tabela_bruta_comercio_internacional['Indicator Category'] == str(lista_categorias[2])]
serv_comerc_df_ic
# Out:
#                  Indicator Category Indicator Code  \
# 11006  Trade in commercial services     ITS_CS_AM6
# 11007  Trade in commercial services     ITS_CS_AM6
# 11008  Trade in commercial services     ITS_CS_AM6
# 11009  Trade in commercial services     ITS_CS_AM6
# 11010  Trade in commercial services     ITS_CS_AM6
# ...                             ...            ...
# 97659  Trade in commercial services      ITS_CS_QX
# 97660  Trade in commercial services      ITS_CS_QX
# 97661  Trade in commercial services      ITS_CS_QX
# 97662  Trade in commercial services      ITS_CS_QX
# 97663  Trade in commercial services      ITS_CS_QX
#
#                                                         Indicator  \
# 11006  Commercial services imports by sector and partner  annual
# 11007  Commercial services imports by sector and partner  annual
# 11008  Commercial services imports by sector and partner  annual
# 11009  Commercial services imports by sector and partner  annual
# 11010  Commercial services imports by sector and partner  annual
# ...                                                           ...
# 97659      Commercial services exports by main sector  quarterly
# 97660      Commercial services exports by main sector  quarterly
# 97661      Commercial services exports by main sector  quarterly
# 97662      Commercial services exports by main sector  quarterly
# 97663      Commercial services exports by main sector  quarterly
#
#       Reporting Economy Code Reporting Economy ISO3A Code Reporting Economy  \
# 11006                    000                          NaN             World
# 11007                    000                          NaN             World
# 11008                    000                          NaN             World
# 11009                    000                          NaN             World
# 11010                    000                          NaN             World
# ...                      ...                          ...               ...
# 97659                    927                          NaN    Euro Area (19)
# 97660                    927                          NaN    Euro Area (19)
# 97661                    927                          NaN    Euro Area (19)
# 97662                    927                          NaN    Euro Area (19)
# 97663                    927                          NaN    Euro Area (19)
#
#       Partner Economy Code Partner Economy ISO3A Code  \
# 11006                  000                        NaN
# 11007                  000                        NaN
# 11008                  000                        NaN
# 11009                  000                        NaN
# 11010                  000                        NaN
# ...                    ...                        ...
# 97659                  ZX9                        NaN
# 97660                  ZX9                        NaN
# 97661                  ZX9                        NaN
# 97662                  ZX9                        NaN
# 97663                  ZX9                        NaN
#
#                   Partner Economy Product/Sector Classification Code  \
# 11006                       World                               BOP6
# 11007                       World                               BOP6
# 11008                       World                               BOP6
# 11009                       World                               BOP6
# 11010                       World                               BOP6
# ...                           ...                                ...
# 97659  Extra Euro Area (19) Trade                               BOP6
# 97660  Extra Euro Area (19) Trade                               BOP6
# 97661  Extra Euro Area (19) Trade                               BOP6
# 97662  Extra Euro Area (19) Trade                               BOP6
# 97663  Extra Euro Area (19) Trade                               BOP6
#
#                                              Product/Sector Classification  \
# 11006  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11007  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11008  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11009  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 11010  Services - Extended Balance of Payments Classification (EBOPS 2010)
# ...                                                                    ...
# 97659  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97660  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97661  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97662  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 97663  Services - Extended Balance of Payments Classification (EBOPS 2010)
#
#       Product/Sector Code             Product/Sector Period Code  \
# 11006                   S  Memo item: Total services           A
# 11007                  SC                  Transport           A
# 11008                 SC1              Sea transport           A
# 11009                SC11            Passenger (Sea)           A
# 11010                SC12              Freight (Sea)           A
# ...                   ...                        ...         ...
# 97659                SPX4     Goods-related services          Q1
# 97660                SPX4     Goods-related services          Q1
# 97661                SPX4     Goods-related services          Q2
# 97662                SPX4     Goods-related services          Q3
# 97663                SPX4     Goods-related services          Q4
#
#                Period Frequency Code  Frequency Unit Code               Unit  \
# 11006          Annual              A     Annual       USM  Million US dollar
# 11007          Annual              A     Annual       USM  Million US dollar
# 11008          Annual              A     Annual       USM  Million US dollar
# 11009          Annual              A     Annual       USM  Million US dollar
# 11010          Annual              A     Annual       USM  Million US dollar
# ...               ...            ...        ...       ...                ...
# 97659   First Quarter              Q  Quarterly       USM  Million US dollar
# 97660   First Quarter              Q  Quarterly       USM  Million US dollar
# 97661  Second Quarter              Q  Quarterly       USM  Million US dollar
# 97662   Third Quarter              Q  Quarterly       USM  Million US dollar
# 97663  Fourth Quarter              Q  Quarterly       USM  Million US dollar
#
#        Year Value Flag Code Value Flag  Text Value         Value
# 11006  2021             NaN        NaN         NaN  5.623458e+06
# 11007  2021             NaN        NaN         NaN  1.374130e+06
# 11008  2021             NaN        NaN         NaN  7.043807e+05
# 11009  2021             NaN        NaN         NaN  2.213825e+04
# 11010  2021             NaN        NaN         NaN  5.446202e+05
# ...     ...             ...        ...         ...           ...
# 97659  2022             NaN        NaN         NaN  1.531211e+04
# 97660  2021             NaN        NaN         NaN  1.333043e+04
# 97661  2021             NaN        NaN         NaN  1.360313e+04
# 97662  2021             NaN        NaN         NaN  1.317543e+04
# 97663  2021             NaN        NaN         NaN  1.560341e+04
#
# [86658 rows x 24 columns]

# %%
#aqui, o mesmo raciocínio usado anteriormente foi feito para listar a coluna indicadores,
#isso é feito para as 3 divisões do DF original

lista_tipos_indices_repet = index_df_ic['Indicator'].tolist()
lista_tipos_indices = []
[lista_tipos_indices.append(indice) for indice in lista_tipos_indices_repet if indice not in lista_tipos_indices]
print(lista_tipos_indices)
# Out:
# ['Merchandise import value chained indices - annual', 'Merchandise import value fixed-base indices - annual', 'Merchandise import volume chained indices - annual', 'Merchandise import volume fixed-base indices - annual', 'Merchandise import volume change - annual', 'Merchandise import unit value chained indices - annual', 'Merchandise import unit value fixed-base indices - annual', 'Merchandise export unit value chained indices - annual', 'Merchandise export unit value fixed-base indices - annual', 'Merchandise export value chained indices - annual', 'Merchandise export value fixed-base indices - annual', 'Merchandise export volume chained indices - annual', 'Merchandise export volume fixed-base indices - annual', 'Merchandise export volume change - annual', 'Import price changes of manufactured goods - monthly', 'Import price indices of manufactured goods - monthly', 'Export price changes of manufactured goods - monthly', 'Export price indices of manufactured goods - monthly', 'Merchandise import volume indices, not seasonally adjusted - quarterly', 'Merchandise import volume indices, seasonally adjusted - quarterly', 'Merchandise export volume indices, not seasonally adjusted - quarterly', 'Merchandise export volume indices, seasonally adjusted - quarterly']

# %%
lista_ind_valores_comerc_repet = values_df_ic['Indicator'].tolist()
lista_ind_valores_comerc = []
[lista_ind_valores_comerc.append(critério) for critério in lista_ind_valores_comerc_repet if critério not in lista_ind_valores_comerc]
print(lista_ind_valores_comerc)
# Out:
# ['Merchandise imports by product group \x96 annual', 'Merchandise exports by product group \x96 annual', 'Total merchandise imports - monthly', 'Total merchandise exports - monthly', 'Total merchandise imports - quarterly', 'Total merchandise exports - quarterly']

# %%
lista_cs_ind_rep = serv_comerc_df_ic['Indicator'].tolist()
lista_cs_ind = []
[lista_cs_ind.append(critério) for critério in lista_cs_ind_rep if critério not in lista_cs_ind]
print(lista_cs_ind)
# Out:
# ['Commercial services imports by sector and partner \x96 annual', 'Commercial services exports by sector and partner \x96 annual', 'Commercial services imports of selected economies \x96 monthly', 'Commercial services imports of selected economies (growth) \x96 monthly', 'Commercial services exports of selected economies \x96 monthly', 'Commercial services exports of selected economies (growth) \x96 monthly', 'Commercial services imports by main sector \x96 quarterly', 'Commercial services exports by main sector \x96 quarterly']

# %%
#Avaliando o número de indicadores de cada parte:

print('indicadores de índice: ',len(lista_tipos_indices))
print('indicadores de valores comerciais: ',len(lista_ind_valores_comerc))
print('indicadores de serviços comerciais: ',len(lista_cs_ind))
# Out:
# indicadores de índice:  22
# indicadores de valores comerciais:  6
# indicadores de serviços comerciais:  8

# %%
#agora, será feita uma segmentação mais direcionada dos dados, para obter as balanças comerciais dos países
#primeiro para produtos e depois para serviços comerciais

Tot_m_expt_monthly = values_df_ic.loc[values_df_ic['Indicator'] == 'Total merchandise exports - monthly']
Tot_m_expt_monthly
# Out:
#             Indicator Category Indicator Code  \
# 8292  Merchandise trade values     ITS_MTV_MX
# 8293  Merchandise trade values     ITS_MTV_MX
# 8294  Merchandise trade values     ITS_MTV_MX
# 8295  Merchandise trade values     ITS_MTV_MX
# 8296  Merchandise trade values     ITS_MTV_MX
# ...                        ...            ...
# 9747  Merchandise trade values     ITS_MTV_MX
# 9748  Merchandise trade values     ITS_MTV_MX
# 9749  Merchandise trade values     ITS_MTV_MX
# 9750  Merchandise trade values     ITS_MTV_MX
# 9751  Merchandise trade values     ITS_MTV_MX
#
#                                 Indicator Reporting Economy Code  \
# 8292  Total merchandise exports - monthly                    008
# 8293  Total merchandise exports - monthly                    008
# 8294  Total merchandise exports - monthly                    008
# 8295  Total merchandise exports - monthly                    008
# 8296  Total merchandise exports - monthly                    008
# ...                                   ...                    ...
# 9747  Total merchandise exports - monthly                    918
# 9748  Total merchandise exports - monthly                    918
# 9749  Total merchandise exports - monthly                    918
# 9750  Total merchandise exports - monthly                    918
# 9751  Total merchandise exports - monthly                    918
#
#      Reporting Economy ISO3A Code Reporting Economy Partner Economy Code  \
# 8292                          ALB           Albania                  000
# 8293                          ALB           Albania                  000
# 8294                          ALB           Albania                  000
# 8295                          ALB           Albania                  000
# 8296                          ALB           Albania                  000
# ...                           ...               ...                  ...
# 9747                          EEC    European Union                  EUT
# 9748                          EEC    European Union                  EUT
# 9749                          EEC    European Union                  EUT
# 9750                          EEC    European Union                  EUT
# 9751                          EEC    European Union                  EUT
#
#      Partner Economy ISO3A Code Partner Economy  \
# 8292                        NaN           World
# 8293                        NaN           World
# 8294                        NaN           World
# 8295                        NaN           World
# 8296                        NaN           World
# ...                         ...             ...
# 9747                        NaN  Extra EU Trade
# 9748                        NaN  Extra EU Trade
# 9749                        NaN  Extra EU Trade
# 9750                        NaN  Extra EU Trade
# 9751                        NaN  Extra EU Trade
#
#      Product/Sector Classification Code  \
# 8292                              SITC3
# 8293                              SITC3
# 8294                              SITC3
# 8295                              SITC3
# 8296                              SITC3
# ...                                 ...
# 9747                              SITC3
# 9748                              SITC3
# 9749                              SITC3
# 9750                              SITC3
# 9751                              SITC3
#
#                    Product/Sector Classification Product/Sector Code  \
# 8292  Merchandise - SITC Revision 3 (aggregates)                  TO
# 8293  Merchandise - SITC Revision 3 (aggregates)                  TO
# 8294  Merchandise - SITC Revision 3 (aggregates)                  TO
# 8295  Merchandise - SITC Revision 3 (aggregates)                  TO
# 8296  Merchandise - SITC Revision 3 (aggregates)                  TO
# ...                                          ...                 ...
# 9747  Merchandise - SITC Revision 3 (aggregates)                  TO
# 9748  Merchandise - SITC Revision 3 (aggregates)                  TO
# 9749  Merchandise - SITC Revision 3 (aggregates)                  TO
# 9750  Merchandise - SITC Revision 3 (aggregates)                  TO
# 9751  Merchandise - SITC Revision 3 (aggregates)                  TO
#
#          Product/Sector Period Code     Period Frequency Code Frequency  \
# 8292  Total merchandise         M01    January              M   Monthly
# 8293  Total merchandise         M01    January              M   Monthly
# 8294  Total merchandise         M02   February              M   Monthly
# 8295  Total merchandise         M02   February              M   Monthly
# 8296  Total merchandise         M03      March              M   Monthly
# ...                 ...         ...        ...            ...       ...
# 9747  Total merchandise         M08     August              M   Monthly
# 9748  Total merchandise         M09  September              M   Monthly
# 9749  Total merchandise         M10    October              M   Monthly
# 9750  Total merchandise         M11   November              M   Monthly
# 9751  Total merchandise         M12   December              M   Monthly
#
#      Unit Code               Unit  Year Value Flag Code Value Flag  \
# 8292       USM  Million US dollar  2021             NaN        NaN
# 8293       USM  Million US dollar  2022             NaN        NaN
# 8294       USM  Million US dollar  2021             NaN        NaN
# 8295       USM  Million US dollar  2022             NaN        NaN
# 8296       USM  Million US dollar  2022             NaN        NaN
# ...        ...                ...   ...             ...        ...
# 9747       USM  Million US dollar  2021             NaN        NaN
# 9748       USM  Million US dollar  2021             NaN        NaN
# 9749       USM  Million US dollar  2021             NaN        NaN
# 9750       USM  Million US dollar  2021             NaN        NaN
# 9751       USM  Million US dollar  2021             NaN        NaN
#
#       Text Value          Value
# 8292         NaN     233.995820
# 8293         NaN     326.086918
# 8294         NaN     242.379575
# 8295         NaN     348.856798
# 8296         NaN     427.600902
# ...          ...            ...
# 9747         NaN  196279.382520
# 9748         NaN  219762.848800
# 9749         NaN  221419.702260
# 9750         NaN  230248.800860
# 9751         NaN  224165.780640
#
# [1460 rows x 24 columns]

# %%
Tot_m_imp_monthly = values_df_ic.loc[values_df_ic['Indicator'] == 'Total merchandise imports - monthly']
Tot_m_imp_monthly
# Out:
#             Indicator Category Indicator Code  \
# 6832  Merchandise trade values     ITS_MTV_MM
# 6833  Merchandise trade values     ITS_MTV_MM
# 6834  Merchandise trade values     ITS_MTV_MM
# 6835  Merchandise trade values     ITS_MTV_MM
# 6836  Merchandise trade values     ITS_MTV_MM
# ...                        ...            ...
# 8287  Merchandise trade values     ITS_MTV_MM
# 8288  Merchandise trade values     ITS_MTV_MM
# 8289  Merchandise trade values     ITS_MTV_MM
# 8290  Merchandise trade values     ITS_MTV_MM
# 8291  Merchandise trade values     ITS_MTV_MM
#
#                                 Indicator Reporting Economy Code  \
# 6832  Total merchandise imports - monthly                    008
# 6833  Total merchandise imports - monthly                    008
# 6834  Total merchandise imports - monthly                    008
# 6835  Total merchandise imports - monthly                    008
# 6836  Total merchandise imports - monthly                    008
# ...                                   ...                    ...
# 8287  Total merchandise imports - monthly                    918
# 8288  Total merchandise imports - monthly                    918
# 8289  Total merchandise imports - monthly                    918
# 8290  Total merchandise imports - monthly                    918
# 8291  Total merchandise imports - monthly                    918
#
#      Reporting Economy ISO3A Code Reporting Economy Partner Economy Code  \
# 6832                          ALB           Albania                  000
# 6833                          ALB           Albania                  000
# 6834                          ALB           Albania                  000
# 6835                          ALB           Albania                  000
# 6836                          ALB           Albania                  000
# ...                           ...               ...                  ...
# 8287                          EEC    European Union                  EUT
# 8288                          EEC    European Union                  EUT
# 8289                          EEC    European Union                  EUT
# 8290                          EEC    European Union                  EUT
# 8291                          EEC    European Union                  EUT
#
#      Partner Economy ISO3A Code Partner Economy  \
# 6832                        NaN           World
# 6833                        NaN           World
# 6834                        NaN           World
# 6835                        NaN           World
# 6836                        NaN           World
# ...                         ...             ...
# 8287                        NaN  Extra EU Trade
# 8288                        NaN  Extra EU Trade
# 8289                        NaN  Extra EU Trade
# 8290                        NaN  Extra EU Trade
# 8291                        NaN  Extra EU Trade
#
#      Product/Sector Classification Code  \
# 6832                              SITC3
# 6833                              SITC3
# 6834                              SITC3
# 6835                              SITC3
# 6836                              SITC3
# ...                                 ...
# 8287                              SITC3
# 8288                              SITC3
# 8289                              SITC3
# 8290                              SITC3
# 8291                              SITC3
#
#                    Product/Sector Classification Product/Sector Code  \
# 6832  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6833  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6834  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6835  Merchandise - SITC Revision 3 (aggregates)                  TO
# 6836  Merchandise - SITC Revision 3 (aggregates)                  TO
# ...                                          ...                 ...
# 8287  Merchandise - SITC Revision 3 (aggregates)                  TO
# 8288  Merchandise - SITC Revision 3 (aggregates)                  TO
# 8289  Merchandise - SITC Revision 3 (aggregates)                  TO
# 8290  Merchandise - SITC Revision 3 (aggregates)                  TO
# 8291  Merchandise - SITC Revision 3 (aggregates)                  TO
#
#          Product/Sector Period Code     Period Frequency Code Frequency  \
# 6832  Total merchandise         M01    January              M   Monthly
# 6833  Total merchandise         M01    January              M   Monthly
# 6834  Total merchandise         M02   February              M   Monthly
# 6835  Total merchandise         M02   February              M   Monthly
# 6836  Total merchandise         M03      March              M   Monthly
# ...                 ...         ...        ...            ...       ...
# 8287  Total merchandise         M08     August              M   Monthly
# 8288  Total merchandise         M09  September              M   Monthly
# 8289  Total merchandise         M10    October              M   Monthly
# 8290  Total merchandise         M11   November              M   Monthly
# 8291  Total merchandise         M12   December              M   Monthly
#
#      Unit Code               Unit  Year Value Flag Code Value Flag  \
# 6832       USM  Million US dollar  2022             NaN        NaN
# 6833       USM  Million US dollar  2021             NaN        NaN
# 6834       USM  Million US dollar  2021             NaN        NaN
# 6835       USM  Million US dollar  2022             NaN        NaN
# 6836       USM  Million US dollar  2022             NaN        NaN
# ...        ...                ...   ...             ...        ...
# 8287       USM  Million US dollar  2021             NaN        NaN
# 8288       USM  Million US dollar  2021             NaN        NaN
# 8289       USM  Million US dollar  2021             NaN        NaN
# 8290       USM  Million US dollar  2021             NaN        NaN
# 8291       USM  Million US dollar  2021             NaN        NaN
#
#       Text Value          Value
# 6832         NaN     512.473273
# 6833         NaN     447.766395
# 6834         NaN     511.202026
# 6835         NaN     642.660725
# 6836         NaN     749.462231
# ...          ...            ...
# 8287         NaN  204600.891600
# 8288         NaN  219771.558600
# 8289         NaN  228282.273810
# 8290         NaN  241594.202720
# 8291         NaN  239110.912080
#
# [1460 rows x 24 columns]

# %%
#df_bc_mensal = Tot_m_expt_monthly[['Reporting Economy', 'Period Code', 'Period', 'Unit', 'Year']].copy()
df_bc_mensal = Tot_m_expt_monthly[['Reporting Economy', 'Period Code', 'Period', 'Unit', 'Year']].reset_index(drop=True)

df_bc_mensal['Export Values'] = Tot_m_expt_monthly['Value'].reset_index(drop=True)
df_bc_mensal['Import Values'] = Tot_m_imp_monthly['Value'].reset_index(drop=True)

df_bc_mensal
# Out:
#      Reporting Economy Period Code     Period               Unit  Year  \
# 0              Albania         M01    January  Million US dollar  2021
# 1              Albania         M01    January  Million US dollar  2022
# 2              Albania         M02   February  Million US dollar  2021
# 3              Albania         M02   February  Million US dollar  2022
# 4              Albania         M03      March  Million US dollar  2022
# ...                ...         ...        ...                ...   ...
# 1455    European Union         M08     August  Million US dollar  2021
# 1456    European Union         M09  September  Million US dollar  2021
# 1457    European Union         M10    October  Million US dollar  2021
# 1458    European Union         M11   November  Million US dollar  2021
# 1459    European Union         M12   December  Million US dollar  2021
#
#       Export Values  Import Values
# 0        233.995820     512.473273
# 1        326.086918     447.766395
# 2        242.379575     511.202026
# 3        348.856798     642.660725
# 4        427.600902     749.462231
# ...             ...            ...
# 1455  196279.382520  204600.891600
# 1456  219762.848800  219771.558600
# 1457  221419.702260  228282.273810
# 1458  230248.800860  241594.202720
# 1459  224165.780640  239110.912080
#
# [1460 rows x 7 columns]

# %%
df_bc_mensal['Saldo'] = df_bc_mensal['Export Values'] - df_bc_mensal['Import Values']

# %%
df_bc_mensal = df_bc_mensal.sort_values(by = ['Year', 'Reporting Economy', 'Period Code']).reset_index(drop=True)
df_bc_mensal
# Out:
#      Reporting Economy Period Code    Period               Unit  Year  \
# 0              Albania         M01   January  Million US dollar  2021
# 1              Albania         M02  February  Million US dollar  2021
# 2              Albania         M03     March  Million US dollar  2021
# 3              Albania         M04     April  Million US dollar  2021
# 4              Albania         M05       May  Million US dollar  2021
# ...                ...         ...       ...                ...   ...
# 1455          Viet Nam         M03     March  Million US dollar  2022
# 1456          Viet Nam         M04     April  Million US dollar  2022
# 1457          Viet Nam         M05       May  Million US dollar  2022
# 1458          Viet Nam         M06      June  Million US dollar  2022
# 1459          Viet Nam         M07      July  Million US dollar  2022
#
#       Export Values  Import Values        Saldo
# 0        233.995820     512.473273  -278.477453
# 1        242.379575     511.202026  -268.822451
# 2        306.073000     622.397413  -316.324413
# 3        278.879735     611.663490  -332.783755
# 4        324.417373     611.597601  -287.180228
# ...             ...            ...          ...
# 1455   34711.505927   32662.639963  2048.865964
# 1456   33316.784815   32467.678962   849.105853
# 1457   30917.898803   32615.979741 -1698.080938
# 1458   32843.366862   32232.750117   610.616745
# 1459   30607.490009   30533.121209    74.368800
#
# [1460 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

# %%
tabela_bruta_comercio_internacional[tabela_bruta_comercio_internacional['Reporting Economy Code'] == '918']
# Out:
#                            Indicator Category Indicator Code  \
# 210    Merchandise trade - indices and prices     ITS_MTP_AM
# 211    Merchandise trade - indices and prices     ITS_MTP_AM
# 212    Merchandise trade - indices and prices     ITS_MTP_AM
# 465    Merchandise trade - indices and prices    ITS_MTP_AMF
# 466    Merchandise trade - indices and prices    ITS_MTP_AMF
# ...                                       ...            ...
# 61555            Trade in commercial services   ITS_CS_MM_GR
# 61556            Trade in commercial services   ITS_CS_MM_GR
# 61557            Trade in commercial services   ITS_CS_MM_GR
# 61558            Trade in commercial services   ITS_CS_MM_GR
# 61559            Trade in commercial services   ITS_CS_MM_GR
#
#                                                                   Indicator  \
# 210                       Merchandise import value chained indices - annual
# 211                       Merchandise import value chained indices - annual
# 212                       Merchandise import value chained indices - annual
# 465                    Merchandise import value fixed-base indices - annual
# 466                    Merchandise import value fixed-base indices - annual
# ...                                                                     ...
# 61555  Commercial services imports of selected economies (growth)  monthly
# 61556  Commercial services imports of selected economies (growth)  monthly
# 61557  Commercial services imports of selected economies (growth)  monthly
# 61558  Commercial services imports of selected economies (growth)  monthly
# 61559  Commercial services imports of selected economies (growth)  monthly
#
#       Reporting Economy Code Reporting Economy ISO3A Code Reporting Economy  \
# 210                      918                          EEC    European Union
# 211                      918                          EEC    European Union
# 212                      918                          EEC    European Union
# 465                      918                          EEC    European Union
# 466                      918                          EEC    European Union
# ...                      ...                          ...               ...
# 61555                    918                          EEC    European Union
# 61556                    918                          EEC    European Union
# 61557                    918                          EEC    European Union
# 61558                    918                          EEC    European Union
# 61559                    918                          EEC    European Union
#
#       Partner Economy Code Partner Economy ISO3A Code Partner Economy  \
# 210                    000                        NaN           World
# 211                    918                        EEC  European Union
# 212                    EUT                        NaN  Extra EU Trade
# 465                    000                        NaN           World
# 466                    918                        EEC  European Union
# ...                    ...                        ...             ...
# 61555                  EUT                        NaN  Extra EU Trade
# 61556                  EUT                        NaN  Extra EU Trade
# 61557                  EUT                        NaN  Extra EU Trade
# 61558                  EUT                        NaN  Extra EU Trade
# 61559                  EUT                        NaN  Extra EU Trade
#
#       Product/Sector Classification Code  \
# 210                                SITC3
# 211                                SITC3
# 212                                SITC3
# 465                                SITC3
# 466                                SITC3
# ...                                  ...
# 61555                               BOP6
# 61556                               BOP6
# 61557                               BOP6
# 61558                               BOP6
# 61559                               BOP6
#
#                                              Product/Sector Classification  \
# 210                             Merchandise - SITC Revision 3 (aggregates)
# 211                             Merchandise - SITC Revision 3 (aggregates)
# 212                             Merchandise - SITC Revision 3 (aggregates)
# 465                             Merchandise - SITC Revision 3 (aggregates)
# 466                             Merchandise - SITC Revision 3 (aggregates)
# ...                                                                    ...
# 61555  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 61556  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 61557  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 61558  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 61559  Services - Extended Balance of Payments Classification (EBOPS 2010)
#
#       Product/Sector Code             Product/Sector Period Code     Period  \
# 210                    TO          Total merchandise           A     Annual
# 211                    TO          Total merchandise           A     Annual
# 212                    TO          Total merchandise           A     Annual
# 465                    TO          Total merchandise           A     Annual
# 466                    TO          Total merchandise           A     Annual
# ...                   ...                        ...         ...        ...
# 61555                   S  Memo item: Total services         M08     August
# 61556                   S  Memo item: Total services         M09  September
# 61557                   S  Memo item: Total services         M10    October
# 61558                   S  Memo item: Total services         M11   November
# 61559                   S  Memo item: Total services         M12   December
#
#       Frequency Code Frequency Unit Code  \
# 210                A    Annual       IDP
# 211                A    Annual       IDP
# 212                A    Annual       IDP
# 465                A    Annual      ID15
# 466                A    Annual      ID15
# ...              ...       ...       ...
# 61555              M   Monthly       YOY
# 61556              M   Monthly       YOY
# 61557              M   Monthly       YOY
# 61558              M   Monthly       YOY
# 61559              M   Monthly       YOY
#
#                                                      Unit  Year  \
# 210                                     Previous year=100  2021
# 211                                     Previous year=100  2021
# 212                                     Previous year=100  2021
# 465                                              2015=100  2021
# 466                                              2015=100  2021
# ...                                                   ...   ...
# 61555  % change over the same period of the previous year  2021
# 61556  % change over the same period of the previous year  2021
# 61557  % change over the same period of the previous year  2021
# 61558  % change over the same period of the previous year  2021
# 61559  % change over the same period of the previous year  2021
#
#       Value Flag Code Value Flag  Text Value    Value
# 210               NaN        NaN         NaN  125.264
# 211               NaN        NaN         NaN  124.136
# 212               NaN        NaN         NaN  127.100
# 465               NaN        NaN         NaN  140.085
# 466               NaN        NaN         NaN  142.527
# ...               ...        ...         ...      ...
# 61555             NaN        NaN         NaN   28.000
# 61556             NaN        NaN         NaN   16.000
# 61557             NaN        NaN         NaN   13.000
# 61558             NaN        NaN         NaN   12.000
# 61559             NaN        NaN         NaN    5.000
#
# [640 rows x 24 columns]

# %%
lista_rep_RE = tabela_bruta_comercio_internacional['Reporting Economy'].tolist()
lista_RE = []
[lista_RE.append(economy) for economy in lista_rep_RE if economy not in lista_RE]
print(lista_RE)
# Out:
# ['World', 'Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Angola', 'Antigua and Barbuda', 'Azerbaijan', 'Argentina', 'Australia', 'Austria', 'Bahamas', 'Bahrain, Kingdom of', 'Bangladesh', 'Armenia', 'Barbados', 'Belgium', 'Bermuda', 'Bhutan', 'Bolivia, Plurinational State of', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Belize', 'Solomon Islands', 'Brunei Darussalam', 'Bulgaria', 'Myanmar', 'Burundi', 'Belarus', 'Cambodia', 'Cameroon', 'Canada', 'Cabo Verde', 'Cayman Islands', 'Central African Republic', 'Sri Lanka', 'Chad', 'Chile', 'China', 'Chinese Taipei', 'Colombia', 'Comoros', 'Congo', 'Democratic Republic of the Congo', 'Cook Islands', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Benin', 'Denmark', 'Dominica', 'Dominican Republic', 'Ecuador', 'El Salvador', 'Equatorial Guinea', 'Ethiopia', 'Eritrea', 'Estonia', 'Fiji', 'Finland', 'France', 'French Polynesia', 'Djibouti', 'Gabon', 'Georgia', 'The Gambia', 'Germany', 'Ghana', 'Kiribati', 'Greece', 'Greenland', 'Grenada', 'Guam', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy', "Côte d'Ivoire", 'Jamaica', 'Japan', 'Kazakhstan', 'Jordan', 'Kenya', "Korea, Democratic People's Republic of", 'Korea, Republic of', 'Kuwait, the State of', 'Kyrgyz Republic', "Lao People's Democratic Republic", 'Lebanese Republic', 'Lesotho', 'Latvia', 'Liberia', 'Libya', 'Lithuania', 'Luxembourg', 'Macao, China', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Mauritania', 'Mauritius', 'Mexico', 'Mongolia', 'Moldova, Republic of', 'Montserrat', 'Morocco', 'Mozambique', 'Oman', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'Curaçao', 'Aruba, the Netherlands with respect to', 'Saint Martin', 'New Caledonia', 'Vanuatu', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norway', 'Northern Mariana Islands', 'Micronesia, Federated States of', 'Marshall Islands', 'Palau', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Guinea-Bissau', 'Timor-Leste', 'Qatar', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines', 'Sao Tomé and Principe', 'Saudi Arabia, Kingdom of', 'Senegal', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovak Republic', 'Viet Nam', 'Slovenia', 'South Africa', 'Zimbabwe', 'Spain', 'Sudan', 'Suriname', 'Eswatini', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan', 'Thailand', 'Togo', 'Tonga', 'Trinidad and Tobago', 'United Arab Emirates', 'Tunisia', 'Türkiye', 'Turkmenistan', 'Tuvalu', 'Uganda', 'Ukraine', 'North Macedonia', 'Egypt', 'United Kingdom', 'Tanzania', 'United States of America', 'Burkina Faso', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of', 'Samoa', 'Yemen', 'Serbia', 'Montenegro', 'Zambia', 'WTO Members', 'WTO Observer governments', 'Europe', 'Commonwealth of Independent States (CIS), including certain associate and former member States', 'European Union', 'Euro Area (19)', 'North America', 'South and Central America and the Caribbean', 'Andean Community (ANDEAN)', 'Central American Common Market (CACM)', 'North American Free Trade Agreement (NAFTA)', 'Caribbean Community (CARICOM)', 'Pacific Alliance', 'ECCAS (Economic Community of Central African States)', 'Southern Common Market (MERCOSUR) excluding Venezuela, Bolivarian Republic of', 'OPEC (Organization of the Petroleum Exporting Countries)', 'G-7 (Group of Seven)', 'Four East Asian traders', 'Six East Asian traders', 'Africa', 'West African Economic and Monetary Union (WAEMU)', 'Common Market for Eastern and Southern Africa (COMESA)', 'West African Economic Community (ECOWAS)', 'Southern African Development Community (SADC)', 'African, Caribbean and Pacific States (ACP)', 'Central African Economic and Monetary Community (CAEMC)', 'Middle East', 'Gulf Cooperation Council (GCC)', 'Asia', ' ...

# %%
lista_rep_REcode = tabela_bruta_comercio_internacional['Reporting Economy Code'].tolist()
lista_REcode = []
[lista_REcode.append(economy) for economy in lista_rep_REcode if economy not in lista_REcode]
print(lista_REcode)
# Out:
# ['000', '004', '008', '012', '016', '024', '028', '031', '032', '036', '040', '044', '048', '050', '051', '052', '056', '060', '064', '068', '070', '072', '076', '084', '090', '096', '100', '104', '108', '112', '116', '120', '124', '132', '136', '140', '144', '148', '152', '156', '158', '170', '174', '178', '180', '184', '188', '191', '192', '196', '203', '204', '208', '212', '214', '218', '222', '226', '231', '232', '233', '242', '246', '250', '258', '262', '266', '268', '270', '276', '288', '296', '300', '304', '308', '316', '320', '324', '328', '332', '340', '344', '348', '352', '356', '360', '364', '368', '372', '376', '380', '384', '388', '392', '398', '400', '404', '408', '410', '414', '417', '418', '422', '426', '428', '430', '434', '440', '442', '446', '450', '454', '458', '462', '466', '470', '478', '480', '484', '496', '498', '500', '504', '508', '512', '516', '520', '524', '528', '531', '533', '534', '540', '548', '554', '558', '562', '566', '570', '578', '580', '583', '584', '585', '586', '591', '598', '600', '604', '608', '616', '620', '624', '626', '634', '642', '643', '646', '659', '662', '666', '670', '678', '682', '686', '690', '694', '702', '703', '704', '705', '710', '716', '724', '736', '740', '748', '752', '756', '760', '762', '764', '768', '776', '780', '784', '788', '792', '795', '798', '800', '804', '807', '818', '826', '834', '840', '854', '858', '860', '862', '882', '887', '892', '893', '894', '900', '902', '905', '910', '918', '927', '931', '932', '937', '938', '940', '941', '942', '943', '944', '945', '946', '948', '949', '950', '957', '958', '959', '961', '962', '964', '965', '966', '970', '975', '977', '980', '981', '982', '983', '985', '986', '997', 'LAX', 'LFX', 'LMX', 'LOX', 'OAF', 'OAS', 'OCI', 'OSE', 'OWE', '092', '292', '706', '923', '020', '535', '660', '772', '796', '876', '947', '992', '728', 410, 428, 440, 442, 470, 496, 504, 586, 608, 616, 620, 642, 643, 703, 705, 724, 752, 792, 800, 804, 807, 826, 834, 840, 892, 918, 927, 36, 50, 56, 76, 100, 112, 124, 156, 191, 203, 208, 233, 246, 250, 276, 300, 348, 356, 380, 392, 404, 4, 8, 12, 24, 31, 32, 40, 44, 51, 60, 64, 68, 70, 72, 84, 90, 96, 104, 116, 132, 144, 152, 158, 170, 188, 196, 214, 218, 222, 231, 242, 268, 270, 288, 320, 324, 328, 332, 340, 344, 352, 360, 364, 368, 372, 376, 388, 398, 400, 414, 417, 418, 426, 430, 446, 450, 458, 480, 484, 498, 508, 516, 524, 528, 531, 533, 534, 548, 554, 558, 566, 578, 591, 598, 600, 604, 626, 634, 646, 678, 682, 690, 702, 704, 710, 716, 736, 740, 748, 756, 762, 764, 776, 780, 788, 818, 858, 860, 882, 893, 894]

# %%
df = tabela_bruta_comercio_internacional.drop_duplicates(subset=['Reporting Economy','Reporting Economy Code'])
df[['Reporting Economy','Reporting Economy Code']]
# Out:
#       Reporting Economy Reporting Economy Code
# 0                 World                    000
# 1           Afghanistan                    004
# 2               Albania                    008
# 3               Algeria                    012
# 4        American Samoa                    016
# ...                 ...                    ...
# 87500           Uruguay                    858
# 87575        Uzbekistan                    860
# 87650             Samoa                    882
# 87793        Montenegro                    893
# 87868            Zambia                    894
#
# [415 rows x 2 columns]

# %%
 tabela_bruta_comercio_internacional[tabela_bruta_comercio_internacional['Reporting Economy Code'].str.contains('992', na = False)]
# Out:
#                  Indicator Category Indicator Code  \
# 6557       Merchandise trade values     ITS_MTV_AM
# 6821       Merchandise trade values     ITS_MTV_AX
# 26722  Trade in commercial services     ITS_CS_AM6
# 26723  Trade in commercial services     ITS_CS_AM6
# 26724  Trade in commercial services     ITS_CS_AM6
# ...                             ...            ...
# 44133  Trade in commercial services     ITS_CS_AX6
# 44134  Trade in commercial services     ITS_CS_AX6
# 44135  Trade in commercial services     ITS_CS_AX6
# 44136  Trade in commercial services     ITS_CS_AX6
# 44137  Trade in commercial services     ITS_CS_AX6
#
#                                                         Indicator  \
# 6557                Merchandise imports by product group  annual
# 6821                Merchandise exports by product group  annual
# 26722  Commercial services imports by sector and partner  annual
# 26723  Commercial services imports by sector and partner  annual
# 26724  Commercial services imports by sector and partner  annual
# ...                                                           ...
# 44133  Commercial services exports by sector and partner  annual
# 44134  Commercial services exports by sector and partner  annual
# 44135  Commercial services exports by sector and partner  annual
# 44136  Commercial services exports by sector and partner  annual
# 44137  Commercial services exports by sector and partner  annual
#
#       Reporting Economy Code Reporting Economy ISO3A Code  \
# 6557                     992                          NaN
# 6821                     992                          NaN
# 26722                    992                          NaN
# 26723                    992                          NaN
# 26724                    992                          NaN
# ...                      ...                          ...
# 44133                    992                          NaN
# 44134                    992                          NaN
# 44135                    992                          NaN
# 44136                    992                          NaN
# 44137                    992                          NaN
#
#                      Reporting Economy Partner Economy Code  \
# 6557   Landlocked developing countries                  000
# 6821   Landlocked developing countries                  000
# 26722  Landlocked developing countries                  000
# 26723  Landlocked developing countries                  000
# 26724  Landlocked developing countries                  000
# ...                                ...                  ...
# 44133  Landlocked developing countries                  000
# 44134  Landlocked developing countries                  000
# 44135  Landlocked developing countries                  000
# 44136  Landlocked developing countries                  000
# 44137  Landlocked developing countries                  000
#
#       Partner Economy ISO3A Code Partner Economy  \
# 6557                         NaN           World
# 6821                         NaN           World
# 26722                        NaN           World
# 26723                        NaN           World
# 26724                        NaN           World
# ...                          ...             ...
# 44133                        NaN           World
# 44134                        NaN           World
# 44135                        NaN           World
# 44136                        NaN           World
# 44137                        NaN           World
#
#       Product/Sector Classification Code  \
# 6557                               SITC3
# 6821                               SITC3
# 26722                               BOP6
# 26723                               BOP6
# 26724                               BOP6
# ...                                  ...
# 44133                               BOP6
# 44134                               BOP6
# 44135                               BOP6
# 44136                               BOP6
# 44137                               BOP6
#
#                                              Product/Sector Classification  \
# 6557                            Merchandise - SITC Revision 3 (aggregates)
# 6821                            Merchandise - SITC Revision 3 (aggregates)
# 26722  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 26723  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 26724  Services - Extended Balance of Payments Classification (EBOPS 2010)
# ...                                                                    ...
# 44133  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 44134  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 44135  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 44136  Services - Extended Balance of Payments Classification (EBOPS 2010)
# 44137  Services - Extended Balance of Payments Classification (EBOPS 2010)
#
#       Product/Sector Code                                   Product/Sector  \
# 6557                   TO                                Total merchandise
# 6821                   TO                                Total merchandise
# 26722                   S                        Memo item: Total services
# 26723                  SC                                        Transport
# 26724                  SD                                           Travel
# ...                   ...                                              ...
# 44133                  SL  Memo item: Government goods and services n.i.e.
# 44134                 SOX                              Commercial services
# 44135                SOX1                        Other commercial services
# 44136                SPX1                        Memo item: Other services
# 44137                SPX4                           Goods-related services
#
#       Period Code  Period Frequency Code Frequency Unit Code  \
# 6557            A  Annual              A    Annual       USM
# 6821            A  Annual              A    Annual       USM
# 26722           A  Annual              A    Annual       USM
# 26723           A  Annual              A    Annual       USM
# 26724           A  Annual              A    Annual       USM
# ...           ...     ...            ...       ...       ...
# 44133           A  Annual              A    Annual       USM
# 44134           A  Annual              A    Annual       USM
# 44135           A  Annual              A    Annual       USM
# 44136           A  Annual              A    Annual       USM
# 44137           A  Annual              A    Annual       USM
#
#                     Unit  Year Value Flag Code Value Flag  Text Value  \
# 6557   Million US dollar  2021             NaN        NaN         NaN
# 6821   Million US dollar  2021             NaN        NaN         NaN
# 26722  Million US dollar  2021             NaN        NaN         NaN
# 26723  Million US dollar  2021             NaN        NaN         NaN
# 26724  Million US dollar  2021             NaN        NaN         NaN
# ...                  ...   ...             ...        ...         ...
# 44133  Million US dollar  2021             NaN        NaN         NaN
# 44134  Million US dollar  2021             NaN        NaN         NaN
# 44135  Million US dollar  2021             NaN        NaN         NaN
# 44136  Million US dollar  2021             NaN        NaN         NaN
# 44137  Million US dollar  2021             NaN        NaN         NaN
#
#                Value
# 6557   250168.787953
# 6821   219128.615821
# 26722   63589.433840
# 26723   27547.966395
# 26724    9283.808049
# ...              ...
# 44133    2134.821493
# 44134   33875.207774
# 44135    8863.198496
# 44136   10998.017989
# 44137    1219.669355
#
# [43 rows x 24 columns]
